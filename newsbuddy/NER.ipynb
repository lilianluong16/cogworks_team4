# %%
import nltk, pickle
import numpy as np
from nltk.tokenize import word_tokenize
from collections import Counter
import os
from os import path, makedirs
import news_loader

# %%
def extract_single(tokens, by_type=False):
    """
    Gets the named entities in the list of tokens
    
    Parameters:
    -----------
    tokens:
        a tokenized document containing named entities
    
    Returns:
    --------
    list of strings:
        each string is the name of an entity
    """
    entities = []
    pos = nltk.pos_tag(tokens) # label parts of speech
    named_entities = nltk.ne_chunk(pos, binary=not by_type) # identify named entities
    for i in range(0, len(named_entities)):
        ents = named_entities.pop()
        if getattr(ents, 'label', None) != None and ents.label() == "NE": 
            entities.append(([ne for ne in ents]))
    extracted = np.array(entities)
    if extracted.ndim == 3:
        final = extracted[:,:,0].tolist()
    else:
        final = []
        for entity in extracted:
            final.append(np.array(entity)[:,0].tolist())
    r = []
    for entity in final:
        entity = " ".join(entity)
        r.append(entity)
    return r

# %%
def relate_entities(extracted):
    """
    
    Returns:
    --------
        Counter:
            
    """
    occurences = Counter(extracted)
    return occurences

# %%
def create_db(extracted=None):
    """
    Creates a database of named entities occuring the supplied article
    
    Parameters:
    -----------
    extracted (list of strings):
        the extracted named entities from a single documetn
        
    Returns:
    --------
    dictionary (string --> Counter):
        database relating the named entities to 
    """
    global db
    db = {}
    if extracted is not None:
        for entity in extracted:
            db[entity] = Counter(extracted)
            del db[entity][entity]
    return db

# %%
def update_single(extracted):
    for entity in extracted:
        if entity in db:
            db[entity].update(Counter(extracted))
        else:
            db[entity] = Counter(extracted)
        del db[entity][entity]
    return db

# %%
DATABASE_FR = "data/entities_database.txt"

# %%
def new_database(filepath=DATABASE_FR):
    """
    Creates a new text file and folder in the filepath; uses 

    If creating additional filepaths, specify it in the filepath variable 
    in all functions with the filepath kwarg
    """
    if not os.path.exists(filepath):
        os.makedirs(str.partition(filepath, "/")[0])
        with open(filepath, "w+"):
            pass

new_database(filepath=DATABASE_FR)

# %%
def write_database(filepath=DATABASE_FR):
    with open(filepath, "wb") as f:
        pickle.dump(db, f)

# %%
def retrieve_database(filepath=DATABASE_FR):
    with open(filepath, "rb") as f:
        db = pickle.load(f)
    return db

# %%
def clear_database(filepath=DATABASE_FR):
    db = {}
    with open(filepath, "wb") as f:
        pickle.dump(db, f)

# %%
def top_related(entity):
    return db[entity].most_common()

# %%
def update(docs):
    for doc in docs:
        update_single(extract_single(doc))
    return db

# %%
docs = news_loader.for_ner(filter_text=False)
print(docs[0])
# Out:
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/fwIVm9YOgzo/us-cyber-france-facebook-spies-exclusive-idUSKBN1AC0EI
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/5S-3l10j6wQ/us-usa-trump-russia-sanctions-idUSKBN1AC1U8
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/_H47_5h6Up4/us-britain-baby-idUSKBN1AC1C1
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/MVgH3StW3FI/us-israel-palestinians-idUSKBN1AC0UF
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/Rfs2YUfZuX8/us-usa-northkorea-army-idUSKBN1AC2V3
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/BkvXqd7sJk4/us-mideast-crisis-syria-un-idUSKBN1AC315
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/9gthxn-Unx4/us-nigeria-security-idUSKBN1AC30B
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/jUGQkMqtkW8/us-poland-politics-judiciary-kaczynski-idUSKBN1AC2R4
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/WEP96rO-BgE/us-mideast-crisis-russia-syria-idUSKBN1AC1R9
# downloading: http://feeds.reuters.com/~r/Reuters/worldNews/~3/Yt63vK5mh4Y/us-venezuela-politics-idUSKBN1AC1S9
# ['Exclusive', ':', 'Russia', 'used', 'Facebook', 'to', 'try', 'to', 'spy', 'on', 'Macron', 'campaign', '-', 'sources', 'SAN', 'FRANCISCO', '(', 'Reuters', ')', '-', 'Russian', 'intelligence', 'agents', 'attempted', 'to', 'spy', 'on', 'President', 'Emmanuel', 'Macron', "'s", 'election', 'campaign', 'earlier', 'this', 'year', 'by', 'creating', 'phony', 'Facebook', 'personas', ',', 'according', 'to', 'a', 'U.S', '.', 'Congressman', 'and', 'two', 'other', 'people', 'briefed', 'on', 'the', 'effort', '.', 'About', 'two', 'dozen', 'Facebook', 'accounts', 'were', 'created', 'to', 'conduct', 'surveillance', 'on', 'Macron', 'campaign', 'officials', 'and', 'others', 'close', 'to', 'the', 'centrist', 'former', 'financier', 'as', 'he', 'sought', 'to', 'defeat', 'far-right', 'nationalist', 'Marine', 'Le', 'Pen', 'and', 'other', 'opponents', 'in', 'the', 'two-round', 'election', ',', 'the', 'sources', 'said', '.', 'Macron', 'won', 'in', 'a', 'landslide', 'in', 'May', '.', 'Facebook', 'said', 'in', 'April', 'it', 'had', 'taken', 'action', 'against', 'fake', 'accounts', 'that', 'were', 'spreading', 'misinformation', 'about', 'the', 'French', 'election', '.', 'But', 'the', 'effort', 'to', 'infiltrate', 'the', 'social', 'networks', 'of', 'Macron', 'officials', 'has', 'not', 'previously', 'been', 'reported', '.', 'Russia', 'has', 'repeatedly', 'denied', 'interfering', 'in', 'the', 'French', 'election', 'by', 'hacking', 'and', 'leaking', 'emails', 'and', 'documents', '.', 'U.S.', 'intelligence', 'agencies', 'told', 'Reuters', 'in', 'May', 'that', 'hackers', 'with', 'connections', 'to', 'the', 'Russian', 'government', 'were', 'involved', ',', 'but', 'they', 'did', 'not', 'have', 'conclusive', 'evidence', 'that', 'the', 'Kremlin', 'ordered', 'the', 'hacking', '.', 'Facebook', 'confirmed', 'to', 'Reuters', 'that', 'it', 'had', 'detected', 'spying', 'accounts', 'in', 'France', 'and', 'deactivated', 'them', '.', 'It', 'credited', 'a', 'combination', 'of', 'improved', 'automated', 'detection', 'and', 'stepped-up', 'human', 'efforts', 'to', 'find', 'sophisticated', 'attacks', '.', 'Company', 'officials', 'briefed', 'congressional', 'committee', 'members', 'and', 'staff', ',', 'among', 'others', ',', 'about', 'their', 'findings', '.', 'People', 'involved', 'in', 'the', 'conversations', 'also', 'said', 'the', 'number', 'of', 'Facebook', 'accounts', 'suspended', 'in', 'France', 'for', 'promoting', 'propaganda', 'or', 'spam', '-', 'much', 'of', 'it', 'related', 'to', 'the', 'election', '-', 'had', 'climbed', 'to', '70,000', ',', 'a', 'big', 'jump', 'from', 'the', '30,000', 'account', 'closures', 'the', 'company', 'disclosed', 'in', 'April', '.', 'Facebook', 'did', 'not', 'dispute', 'the', 'figure', '.', 'On', 'Thursday', 'Kremlin', 'spokesman', 'Dmitry', 'Peskov', 'dismissed', 'the', 'accusations', 'that', 'Russia', 'had', 'attempted', 'to', 'influence', 'the', 'French', 'election', 'as', '``', 'a', 'lie', 'and', 'not', 'true', "''", '.', 'Seeking', 'Friends', 'of', 'Friends', 'The', 'spying', 'campaign', 'included', 'Russian', 'agents', 'posing', 'as', 'friends', 'of', 'friends', 'of', 'Macron', 'associates', 'and', 'trying', 'to', 'glean', 'personal', 'information', 'from', 'them', ',', 'according', 'to', 'the', 'U.S.', 'congressman', 'and', 'two', 'others', 'briefed', 'on', 'the', 'matter', '.', 'Facebook', 'employees', 'noticed', 'the', 'efforts', 'during', 'the', 'first', 'round', 'of', 'the', 'presidential', 'election', 'and', 'traced', 'them', 'to', 'tools', 'used', 'in', 'the', 'past', 'by', 'Russia', '’', 's', 'GRU', 'military', 'intelligence', 'unit', ',', 'said', 'the', 'people', ',', 'who', 'spoke', 'on', 'condition', 'they', 'not', 'be', 'named', 'because', 'they', 'were', 'discussing', 'sensitive', 'government', 'and', 'private', 'intelligence', '.', 'FILE', 'PHOTO', '-', 'French', 'President', 'Emmanuel', 'Macron', 'leaves', 'the', 'polling', 'station', 'after', 'voting', 'in', 'the', 'first', 'of', 'two', 'rounds', 'of', 'parliamentary', 'ele ...

# %%
extraction = update(docs)

# %%
db
# Out:
# {'Abdullah': Counter({'Amman': 2,
#           'Aqsa': 4,
#           'Benjamin Netanyahu': 2,
#           'CCTV': 2,
#           'Donald Trump': 2,
#           'East Jerusalem': 8,
#           'Embassy': 4,
#           'Holy Land': 2,
#           'Islam': 2,
#           'Israel': 24,
#           'Israeli': 16,
#           'JERUSALEM': 2,
#           'Jerusalem': 8,
#           'Jordan': 6,
#           'Judaism': 2,
#           'L5N1KI8C8': 2,
#           'Middle East': 4,
#           'Muslim': 6,
#           'Muslim Arab': 2,
#           'Muslims': 8,
#           'Naftali Bennett': 2,
#           'Netanyahu': 16,
#           'Noble Sanctuary': 6,
#           'Old City': 4,
#           'Palestinian': 12,
#           'Palestinians': 2,
#           'Temple': 2,
#           'Temple Mount': 2,
#           'U.S.': 2,
#           'United Nations': 4,
#           'Waqf': 2,
#           'Waqf Muslim': 2,
#           'West Bank': 2,
#           'Western Wall': 2}),
#  'Ahmed Mohammed': Counter({'Islamist': 1,
#           'Lake Chad Basin': 2,
#           'Maiduguri': 1,
#           'NNPC': 2,
#           'Nigeria': 2,
#           'Nigerian National Petroleum Corporation': 1,
#           'Northeastern Nigeria': 1,
#           'University': 1}),
#  'Alaska': Counter({'Army': 2,
#           'Capitol Hill': 1,
#           'Cynthia Osterman': 1,
#           'DIA': 1,
#           'David Brunnstrom': 1,
#           'Defense Intelligence Agency': 1,
#           'General Paul Selva': 1,
#           'Grant': 1,
#           'Idrees Ali': 1,
#           'Korean': 1,
#           'Milley': 1,
#           'National Press Club': 1,
#           'North': 1,
#           'North Korea': 9,
#           'Pentagon': 1,
#           'Phil Stewart': 1,
#           'Pyongyang': 1,
#           'Senate Armed Services Committee': 1,
#           'Staff': 1,
#           'U.S.': 7,
#           'U.S. Army': 1,
#           'United States': 2,
#           'WASHINGTON': 1,
#           'Washington': 2}),
#  'Amazonas': Counter({'American': 1,
#           'Avianca': 1,
#           'Barinas': 2,
#           'Carabobo': 1,
#           'Caracas': 6,
#           'Clashes': 1,
#           'Colombian': 1,
#           'Democratic Unity': 1,
#           'Donald Trump': 1,
#           'Hugo Chavez': 1,
#           'INE': 1,
#           'Maduro': 3,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'National Electoral Council': 1,
#           'Nestor Reverol': 1,
#           'Nicolas Maduro': 3,
#           'OPEC': 1,
#           'Penal Forum': 1,
#           'Petare': 1,
#           'Ramon Alvarez': 1,
#           'Riot': 1,
#           'Socialist Party': 2,
#           'South': 1,
#           'United States': 1,
#           'Venezuela': 5,
#           'Venezuelan': 4}),
#  'American': Counter({'Amazonas': 1,
#           'Avianca': 1,
#           'Barinas': 2,
#           'Britain': 2,
#           'Carabobo': 1,
#           'Caracas': 6,
#           'Clashes': 1,
#           'Colombian': 1,
#           'Defence Ministry': 2,
#           'Democratic National Committee': 2,
#           'Democratic Unity': 1,
#           'Dmitry Peskov': 2,
#           'Donald Trump': 1,
#           'Emmanuel Macron': 6,
#           'Facebook': 10,
#           'Fancy Bear': 2,
#           'France': 8,
#           'French': 12,
#           'GRU': 8,
#           'Hugo Chavez': 1,
#           'INE': 1,
#           'Jack Stubbs': 2,
#           'Jonathan Weber': 2,
#           'Joseph Menn': 2,
#           'Kremlin': 4,
#           'Le Mans': 2,
#           'Le Pen': 2,
#           'Le Touquet': 2,
#           'LinkedIn': 2,
#           'MI5': 2,
#           'Macron': 16,
#           'Maduro': 3,
#           'Marine Le Pen': 2,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'Michel Rose': 2,
#           'Moscow': 2,
#           'Mounir Mahjoubi': 2,
#           'National Electoral Council': 1,
#           'Nestor Reverol': 1,
#           'Nicolas Maduro': 3,
#           'OPEC': 1,
#           'PHOTO': 4,
#           'Paris': 2,
#           'Penal Forum': 1,
#           'Petare': 1,
#           'Ramon Alvarez': 1,
#           'Riot': 1,
#           'Ross Colvin': 2,
#           'Russia': 8,
#           'Russian': 8,
#           'SAN': 2,
#           'San Francisco': 2,
#           'Socialist Party': 2,
#           'South': 1,
#           'U.S.': 6,
#           'United States': 1,
#           'Venezuela': 5,
#           'Venezuelan': 4}),
#  'Amman': Counter({'Abdullah': 2,
#           'Aqsa': 2,
#           'Benjamin Netanyahu': 1,
#           'CCTV': 1,
#           'Donald Trump': 1,
#           'East Jerusalem': 4,
#           'Embassy': 2,
#           'Holy Land': 1,
#           'Islam': 1,
#           'Israel': 12,
#           'Israeli': 8,
#           'JERUSALEM': 1,
#           'Jerusalem': 4,
#           'Jordan': 3,
#           'Judaism': 1,
#           'L5N1KI8C8': 1,
#           'Middle East': 2,
#           'Muslim': 3,
#           'Muslim Arab': 1,
#           'Muslims': 4,
#           'Naftali Bennett': 1,
#           'Netanyahu': 8,
#           'Noble Sanctuary': 3,
#           'Old City': 2,
#           'Palestinian': 6,
#           'Palestinians': 1,
#           'Temple': 1,
#           'Temple Mount': 1,
#           'U.S.': 1,
#           'United Nations': 2,
#           'Waqf': 1,
#           'Waqf Muslim': 1,
#           'West Bank': 1,
#           'Western Wall': 1}),
#  'Andrzej Duda': Counter({'Axel Springer': 1,
#           'Commission': 1,
#           'Duda': 2,
#           'EU': 1,
#           'European Commission': 1,
#           'German': 1,
#           'Jaroslaw Kaczynski': 1,
#           'Justice Party': 1,
#           'Kaczynski': 5,
#           'Next Target Kaczynski': 1,
#           'PiS': 5,
#           'Poland': 12,
#           'Polsat': 1,
#           'Scripps Network Interactive': 1,
#           'Supreme Court': 3,
#           'TVN': 1,
#           'U.S.': 1,
#           'Viktor Orban': 1,
#           'Warsaw': 4,
#           'Zygmunt': 1}),
#  'Aqsa': Counter({'Abdullah': 4,
#           'Amman': 2,
#           'Benjamin Netanyahu': 2,
#           'CCTV': 2,
#           'Donald Trump': 2,
#           'East Jerusalem': 8,
#           'Embassy': 4,
#           'Holy Land': 2,
#           'Islam': 2,
#           'Israel': 24,
#           'Israeli': 16,
#           'JERUSALEM': 2,
#           'Jerusalem': 8,
#           'Jordan': 6,
#           'Judaism': 2,
#           'L5N1KI8C8': 2,
#           'Middle East': 4,
#           'Muslim': 6,
#           'Muslim Arab': 2,
#           'Muslims': 8,
#           'Naftali Bennett': 2,
#           'Netanyahu': 16,
#           'Noble Sanctuary': 6,
#           'Old City': 4,
#           'Palestinian': 12,
#           'Palestinians': 2,
#           'Temple': 2,
#           'Temple Mount': 2,
#           'U.S.': 2,
#           'United Nations': 4,
#           'Waqf': 2,
#           'Waqf Muslim': 2,
#           'West Bank': 2,
#           'Western Wall': 2}),
#  'Army': Counter({'Alaska': 2,
#           'Capitol Hill': 2,
#           'Cynthia Osterman': 2,
#           'DIA': 2,
#           'David Brunnstrom': 2,
#           'Defense Intelligence Agency': 2,
#           'General Paul Selva': 2,
#           'Grant': 2,
#           'Idrees Ali': 2,
#           'Korean': 2,
#           'Milley': 2,
#           'National Press Club': 2,
#           'North': 2,
#           'North Korea': 18,
#           'Pentagon': 2,
#           'Phil Stewart': 2,
#           'Pyongyang': 2,
#           'Senate Armed Services Committee': 2,
#           'Staff': 2,
#           'U.S.': 14,
#           'U.S. Army': 2,
#           'United States': 4,
#           'WASHINGTON': 2,
#           'Washington': 4}),
#  'Assad': Counter({'Bashar': 2,
#           'Britain': 6,
#           'China': 2,
#           'Damascus': 1,
#           'France': 2,
#           'Hmeymim': 1,
#           'International Criminal Court': 1,
#           'Iran': 1,
#           'Latakia': 1,
#           'MOSCOW': 1,
#           'Michele Sison': 1,
#           'Middle East': 1,
#           'Moscow': 2,
#           'Mueller': 1,
#           'New York': 1,
#           'Obstacles': 1,
#           'Putin': 2,
#           'REUTERS': 1,
#           'Russia': 12,
#           'Russian': 3,
#           'Security Council': 5,
#           'Syria': 8,
#           'Syrian': 8,
#           'Turkey': 1,
#           'U.N.': 3,
#           'U.S.': 2,
#           'UNITED NATIONS': 1,
#           'United Nations': 1,
#           'United Nations Headquarters': 1,
#           'United Nations Matthew Rycroft': 1,
#           'United States': 2,
#           'Ursula Mueller': 1,
#           'Vladimir Putin': 2,
#           'Zhukovsky': 1}),
#  'Avianca': Counter({'Amazonas': 1,
#           'American': 1,
#           'Barinas': 2,
#           'Carabobo': 1,
#           'Caracas': 6,
#           'Clashes': 1,
#           'Colombian': 1,
#           'Democratic Unity': 1,
#           'Donald Trump': 1,
#           'Hugo Chavez': 1,
#           'INE': 1,
#           'Maduro': 3,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'National Electoral Council': 1,
#           'Nestor Reverol': 1,
#           'Nicolas Maduro': 3,
#           'OPEC': 1,
#           'Penal Forum': 1,
#           'Petare': 1,
#           'Ramon Alvarez': 1,
#           'Riot': 1,
#           'Socialist Party': 2,
#           'South': 1,
#           'United States': 1,
#           'Venezuela': 5,
#           'Venezuelan': 4}),
#  'Axel Springer': Counter({'Andrzej Duda': 1,
#           'Commission': 1,
#           'Duda': 2,
#           'EU': 1,
#           'European Commission': 1,
#           'German': 1,
#           'Jaroslaw Kaczynski': 1,
#           'Justice Party': 1,
#           'Kaczynski': 5,
#           'Next Target Kaczynski': 1,
#           'PiS': 5,
#           'Poland': 12,
#           'Polsat': 1,
#           'Scripps Network Interactive': 1,
#           'Supreme Court': 3,
#           'TVN': 1,
#           'U.S.': 1,
#           'Viktor Orban': 1,
#           'Warsaw': 4,
#           'Zygmunt': 1}),
#  'Barack Obama': Counter({'Barria': 1,
#           'CNN': 2,
#           'Congress': 2,
#           'Corker': 1,
#           'Democratic': 1,
#           'Donald Trump': 2,
#           'Edward Fishman': 1,
#           'European Union': 1,
#           'Finland': 2,
#           'Finnish': 1,
#           'G20': 1,
#           'Germany': 1,
#           'Hamburg': 1,
#           'Iran': 2,
#           'Kremlin': 1,
#           'Moscow': 4,
#           'Mueller': 3,
#           'North Korea': 2,
#           'Obama': 2,
#           'Putin': 2,
#           'Representatives': 1,
#           'Republican': 2,
#           'Republican Trump': 1,
#           'Russia': 3,
#           'Russian': 7,
#           'Sarah Sanders': 1,
#           'Sauli Niinisto': 1,
#           'Scaramucci': 1,
#           'Senate': 4,
#           'Sessions': 1,
#           'Speaker Ryan': 1,
#           'Special Counsel Robert Mueller': 1,
#           'State Department': 1,
#           'Trump': 10,
#           'U.S.': 5,
#           'U.S. House': 3,
#           'Ukraine': 1,
#           'United States': 1,
#           'Vladimir Putin': 2,
#           'Washington': 1,
#           'White House': 3}),
#  'Barinas': Counter({'Amazonas': 2,
#           'American': 2,
#           'Avianca': 2,
#           'Carabobo': 2,
#           'Caracas': 12,
#           'Clashes': 2,
#           'Colombian': 2,
#           'Democratic Unity': 2,
#           'Donald Trump': 2,
#           'Hugo Chavez': 2,
#           'INE': 2,
#           'Maduro': 6,
#           'Martinez Casares': 2,
#           'Merida': 2,
#           'National Electoral Council': 2,
#           'Nestor Reverol': 2,
#           'Nicolas Maduro': 6,
#           'OPEC': 2,
#           'Penal Forum': 2,
#           'Petare': 2,
#           'Ramon Alvarez': 2,
#           'Riot': 2,
#           'Socialist Party': 4,
#           'South': 2,
#           'United States': 2,
#           'Venezuela': 10,
#           'Venezuelan': 8}),
#  'Barria': Counter({'Barack Obama': 1,
#           'CNN': 2,
#           'Congress': 2,
#           'Corker': 1,
#           'Democratic': 1,
#           'Donald Trump': 2,
#           'Edward Fishman': 1,
#           'European Union': 1,
#           'Finland': 2,
#           'Finnish': 1,
#           'G20': 1,
#           'Germany': 1,
#           'Hamburg': 1,
#           'Iran': 2,
#           'Kremlin': 1,
#           'Moscow': 4,
#           'Mueller': 3,
#           'North Korea': 2,
#           'Obama': 2,
#           'Putin': 2,
#           'Representatives': 1,
#           'Republican': 2,
#           'Republican Trump': 1,
#           'Russia': 3,
#           'Russian': 7,
#           'Sarah Sanders': 1,
#           'Sauli Niinisto': 1,
#           'Scaramucci': 1,
#           'Senate': 4,
#           'Sessions': 1,
#           'Speaker Ryan': 1,
#           'Special Counsel Robert Mueller': 1,
#           'State Department': 1,
#           'Trump': 10,
#           'U.S.': 5,
#           'U.S. House': 3,
#           'Ukraine': 1,
#           'United States': 1,
#           'Vladimir Putin': 2,
#           'Washington': 1,
#           'White House': 3}),
#  'Bashar': Counter({'Assad': 2,
#           'Britain': 6,
#           'China': 2,
#           'Damascus': 1,
#           'France': 2,
#           'Hmeymim': 1,
#           'International Criminal Court': 1,
#           'Iran': 1,
#           'Latakia': 1,
#           'MOSCOW': 1,
#           'Michele Sison': 1,
#           'Middle East': 1,
#           'Moscow': 2,
#           'Mueller': 1,
#           'New York': 1,
#           'Obstacles': 1,
#           'Putin': 2,
#           'REUTERS': 1,
#           'Russia': 12,
#           'Russian': 3,
#           'Security Council': 5,
#           'Syria': 8,
#           'Syrian': 8,
#           'Turkey': 1,
#           'U.N.': 3,
#           'U.S.': 2,
#           'UNITED NATIONS': 1,
#           'United Nations': 1,
#           'United Nations Headquarters': 1,
#           'United Nations Matthew Rycroft': 1,
#           'United States': 2,
#           'Ursula Mueller': 1,
#           'Vladimir Putin': 2,
#           'Zhukovsky': 1}),
#  'Benjamin Netanyahu': Counter({'Abdullah': 2,
#           'Amman': 1,
#           'Aqsa': 2,
#           'CCTV': 1,
#           'Donald Trump': 1,
#           'East Jerusalem': 4,
#           'Embassy': 2,
#           'Holy Land': 1,
#           'Islam': 1,
#           'Israel': 12,
#           'Israeli': 8,
#           'JERUSALEM': 1,
#           'Jerusalem': 4,
#           'Jordan': 3,
#           'Judaism': 1,
#           'L5N1KI8C8': 1,
#           'Middle East': 2,
#           'Muslim': 3,
#           'Muslim Arab': 1,
#           'Muslims': 4,
#           'Naftali Bennett': 1,
#           'Netanyahu': 8,
#           'Noble Sanctuary': 3,
#           'Old City': 2,
#           'Palestinian': 6,
#           'Palestinians': 1,
#           'Temple': 1,
#           'Temple Mount': 1,
#           'U.S.': 1,
#           'United Nations': 2,
#           'Waqf': 1,
#           'Waqf Muslim': 1,
#           'West Bank': 1,
#           'Western Wall': 1}),
#  'Britain': Counter({'American': 2,
#           'Assad': 6,
#           'Bashar': 6,
#           'British': 2,
#           'Charlie': 48,
#           'Charlie Gard': 4,
#           'China': 12,
#           'Chris Gard': 4,
#           'Christmas': 2,
#           'Connie Yates': 2,
#           'DNA': 2,
#           'Defence Ministry': 2,
#           'Democratic National Committee': 2,
#           'Dmitry Peskov': 2,
#           'Donald Trump': 2,
#           'Emmanuel Macron': 6,
#           'European Court': 2,
#           'Facebook': 10,
#           'Fancy Bear': 2,
#           'France': 20,
#           'Francis': 2,
#           'French': 12,
#           'GRU': 8,
#           'Great Ormond Street': 2,
#           'Great Ormond Street Hospital': 8,
#           'High Court': 6,
#           'Human Rights': 2,
#           'International Criminal Court': 6,
#           'Iran': 6,
#           'Jack Stubbs': 2,
#           'Jonathan Weber': 2,
#           'Joseph Menn': 2,
#           'Kremlin': 4,
#           'LONDON': 2,
#           'Le Mans': 2,
#           'Le Pen': 2,
#           'Le Touquet': 2,
#           'LinkedIn': 2,
#           'London': 2,
#           'MI5': 2,
#           'Macron': 16,
#           'Marine Le Pen': 2,
#           'Michel Rose': 2,
#           'Michele Sison': 6,
#           'Moscow': 2,
#           'Mounir Mahjoubi': 2,
#           'Mueller': 6,
#           'New York': 6,
#           'Nicholas Francis': 2,
#           'Obstacles': 6,
#           'PHOTO': 4,
#           'Paris': 2,
#           'Pope Francis': 2,
#           'Reuters': 2,
#           'Ross Colvin': 2,
#           'Russia': 50,
#           'Russian': 8,
#           'SAN': 2,
#           'San Francisco': 2,
#           'Security Council': 30,
#           'Syria': 36,
#           'Syrian': 42,
#           'Turkey': 6,
#           'U.N.': 18,
#           'U.S.': 20,
#           'UNITED NATIONS': 6,
#           'United Nations': 6,
#           'United Nations Headquarters': 6,
#           'United Nations Matthew Rycroft': 6,
#           'United States': 18,
#           'Ursula Mueller': 6,
#           'Yates': 2}),
#  'British': Counter({'Britain': 2,
#           'Charlie': 24,
#           'Charlie Gard': 2,
#           'Chris Gard': 2,
#           'Christmas': 1,
#           'Connie Yates': 1,
#           'DNA': 1,
#           'Donald Trump': 1,
#           'European Court': 1,
#           'Francis': 1,
#           'Great Ormond Street': 1,
#           'Great Ormond Street Hospital': 4,
#           'High Court': 3,
#           'Human Rights': 1,
#           'LONDON': 1,
#           'London': 1,
#           'Nicholas Francis': 1,
#           'Pope Francis': 1,
#           'Reuters': 1,
#           'U.S.': 1,
#           'United States': 3,
#           'Yates': 1}),
#  'CCTV': Counter({'Abdullah': 2,
#           'Amman': 1,
#           'Aqsa': 2,
#           'Benjamin Netanyahu': 1,
#           'Donald Trump': 1,
#           'East Jerusalem': 4,
#           'Embassy': 2,
#           'Holy Land': 1,
#           'Islam': 1,
#           'Israel': 12,
#           'Israeli': 8,
#           'JERUSALEM': 1,
#           'Jerusalem': 4,
#           'Jordan': 3,
#           'Judaism': 1,
#           'L5N1KI8C8': 1,
#           'Middle East': 2,
#           'Muslim': 3,
#           'Muslim Arab': 1,
#           'Muslims': 4,
#           'Naftali Bennett': 1,
#           'Netanyahu': 8,
#           'Noble Sanctuary': 3,
#           'Old City': 2,
#           'Palestinian': 6,
#           'Palestinians': 1,
#           'Temple': 1,
#           'Temple Mount': 1,
#           'U.S.': 1,
#           'United Nations': 2,
#           'Waqf': 1,
#           'Waqf Muslim': 1,
#           'West Bank': 1,
#           'Western Wall': 1}),
#  'CNN': Counter({'Barack Obama': 2,
#           'Barria': 2,
#           'Congress': 4,
#           'Corker': 2,
#           'Democratic': 2,
#           'Donald Trump': 4,
#           'Edward Fishman': 2,
#           'European Union': 2,
#           'Finland': 4,
#           'Finnish': 2,
#           'G20': 2,
#           'Germany': 2,
#           'Hamburg': 2,
#           'Iran': 4,
#           'Kremlin': 2,
#           'Moscow': 8,
#           'Mueller': 6,
#           'North Korea': 4,
#           'Obama': 4,
#           'Putin': 4,
#           'Representatives': 2,
#           'Republican': 4,
#           'Republican Trump': 2,
#           'Russia': 6,
#           'Russian': 14,
#           'Sarah Sanders': 2,
#           'Sauli Niinisto': 2,
#           'Scaramucci': 2,
#           'Senate': 8,
#           'Sessions': 2,
#           'Speaker Ryan': 2,
#           'Special Counsel Robert Mueller': 2,
#           'State Department': 2,
#           'Trump': 20,
#           'U.S.': 10,
#           'U.S. House': 6,
#           'Ukraine': 2,
#           'United States': 2,
#           'Vladimir Putin': 4,
#           'Washington': 2,
#           'White House': 6}),
#  'Capitol Hill': Counter({'Alaska': 1,
#           'Army': 2,
#           'Cynthia Osterman': 1,
#           'DIA': 1,
#           'David Brunnstrom': 1,
#           'Defense Intelligence Agency': 1,
#           'General Paul Selva': 1,
#           'Grant': 1,
#           'Idrees Ali': 1,
#           'Korean': 1,
#           'Milley': 1,
#           'National Press Club': 1,
#           'North': 1,
#           'North Korea': 9,
#           'Pentagon': 1,
#           'Phil Stewart': 1,
#           'Pyongyang': 1,
#           'Senate Armed Services Committee': 1,
#           'Staff': 1,
#           'U.S.': 7,
#           'U.S. Army': 1,
#           'United States': 2,
#           'WASHINGTON': 1,
#           'Washington': 2}),
#  'Carabobo': Counter({'Amazonas': 1,
#           'American': 1,
#           'Avianca': 1,
#           'Barinas': 2,
#           'Caracas': 6,
#           'Clashes': 1,
#           'Colombian': 1,
#           'Democratic Unity': 1,
#           'Donald Trump': 1,
#           'Hugo Chavez': 1,
#           'INE': 1,
#           'Maduro': 3,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'National Electoral Council': 1,
#           'Nestor Reverol': 1,
#           'Nicolas Maduro': 3,
#           'OPEC': 1,
#           'Penal Forum': 1,
#           'Petare': 1,
#           'Ramon Alvarez': 1,
#           'Riot': 1,
#           'Socialist Party': 2,
#           'South': 1,
#           'United States': 1,
#           'Venezuela': 5,
#           'Venezuelan': 4}),
#  'Caracas': Counter({'Amazonas': 6,
#           'American': 6,
#           'Avianca': 6,
#           'Barinas': 12,
#           'Carabobo': 6,
#           'Clashes': 6,
#           'Colombian': 6,
#           'Democratic Unity': 6,
#           'Donald Trump': 6,
#           'Hugo Chavez': 6,
#           'INE': 6,
#           'Maduro': 18,
#           'Martinez Casares': 6,
#           'Merida': 6,
#           'National Electoral Council': 6,
#           'Nestor Reverol': 6,
#           'Nicolas Maduro': 18,
#           'OPEC': 6,
#           'Penal Forum': 6,
#           'Petare': 6,
#           'Ramon Alvarez': 6,
#           'Riot': 6,
#           'Socialist Party': 12,
#           'South': 6,
#           'United States': 6,
#           'Venezuela': 30,
#           'Venezuelan': 24}),
#  'Charlie': Counter({'Britain': 48,
#           'British': 24,
#           'Charlie Gard': 48,
#           'Chris Gard': 48,
#           'Christmas': 24,
#           'Connie Yates': 24,
#           'DNA': 24,
#           'Donald Trump': 24,
#           'European Court': 24,
#           'Francis': 24,
#           'Great Ormond Street': 24,
#           'Great Ormond Street Hospital': 96,
#           'High Court': 72,
#           'Human Rights': 24,
#           'LONDON': 24,
#           'London': 24,
#           'Nicholas Francis': 24,
#           'Pope Francis': 24,
#           'Reuters': 24,
#           'U.S.': 24,
#           'United States': 72,
#           'Yates': 24}),
#  'Charlie Gard': Counter({'Britain': 4,
#           'British': 2,
#           'Charlie': 48,
#           'Chris Gard': 4,
#           'Christmas': 2,
#           'Connie Yates': 2,
#           'DNA': 2,
#           'Donald Trump': 2,
#           'European Court': 2,
#           'Francis': 2,
#           'Great Ormond Street': 2,
#           'Great Ormond Street Hospital': 8,
#           'High Court': 6,
#           'Human Rights': 2,
#           'LONDON': 2,
#           'London': 2,
#           'Nicholas Francis': 2,
#           'Pope Francis': 2,
#           'Reuters': 2,
#           'U.S.': 2,
#           'United States': 6,
#           'Yates': 2}),
#  'China': Counter({'Assad': 2,
#           'Bashar': 2,
#           'Britain': 12,
#           'France': 4,
#           'International Criminal Court': 2,
#           'Iran': 2,
#           'Michele Sison': 2,
#           'Mueller': 2,
#           'New York': 2,
#           'Obstacles': 2,
#           'Russia': 14,
#           'Security Council': 10,
#           'Syria': 12,
#           'Syrian': 14,
#           'Turkey': 2,
#           'U.N.': 6,
#           'U.S.': 4,
#           'UNITED NATIONS': 2,
#           'United Nations': 2,
#           'United Nations Headquarters': 2,
#           'United Nations Matthew Rycroft': 2,
#           'United States': 4,
#           'Ursula Mueller': 2}),
#  'Chris Gard': Counter({'Britain': 4,
#           'British': 2,
#           'Charlie': 48,
#           'Charlie Gard': 4,
#           'Christmas': 2,
#           'Connie Yates': 2,
#           'DNA': 2,
#           'Donald Trump': 2,
#           'European Court': 2,
#           'Francis': 2,
#           'Great Ormond Street': 2,
#           'Great Ormond Street Hospital': 8,
#           'High Court': 6,
#           'Human Rights': 2,
#           'LONDON': 2,
#           'London': 2,
#           'Nicholas Francis': 2,
#           'Pope Francis': 2,
#           'Reuters': 2,
#           'U.S.': 2,
#           'United States': 6,
#           'Yates': 2}),
#  'Christmas': Counter({'Britain': 2,
#           'British': 1,
#           'Charlie': 24,
#           'Charlie Gard': 2,
#           'Chris Gard': 2,
#           'Connie Yates': 1,
#           'DNA': 1,
#           'Donald Trump': 1,
#           'European Court': 1,
#           'Francis': 1,
#           'Great Ormond Street': 1,
#           'Great Ormond Street Hospital': 4,
#           'High Court': 3,
#           'Human Rights': 1,
#           'LONDON': 1,
#           'London': 1,
#           'Nicholas Francis': 1,
#           'Pope Francis': 1,
#           'Reuters': 1,
#           'U.S.': 1,
#           'United States': 3,
#           'Yates': 1}),
#  'Clashes': Counter({'Amazonas': 1,
#           'American': 1,
#           'Avianca': 1,
#           'Barinas': 2,
#           'Carabobo': 1,
#           'Caracas': 6,
#           'Colombian': 1,
#           'Democratic Unity': 1,
#           'Donald Trump': 1,
#           'Hugo Chavez': 1,
#           'INE': 1,
#           'Maduro': 3,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'National Electoral Council': 1,
#           'Nestor Reverol': 1,
#           'Nicolas Maduro': 3,
#           'OPEC': 1,
#           'Penal Forum': 1,
#           'Petare': 1,
#           'Ramon Alvarez': 1,
#           'Riot': 1,
#           'Socialist Party': 2,
#           'South': 1,
#           'United States': 1,
#           'Venezuela': 5,
#           'Venezuelan': 4}),
#  'Colombian': Counter({'Amazonas': 1,
#           'American': 1,
#           'Avianca': 1,
#           'Barinas': 2,
#           'Carabobo': 1,
#           'Caracas': 6,
#           'Clashes': 1,
#           'Democratic Unity': 1,
#           'Donald Trump': 1,
#           'Hugo Chavez': 1,
#           'INE': 1,
#           'Maduro': 3,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'National Electoral Council': 1,
#           'Nestor Reverol': 1,
#           'Nicolas Maduro': 3,
#           'OPEC': 1,
#           'Penal Forum': 1,
#           'Petare': 1,
#           'Ramon Alvarez': 1,
#           'Riot': 1,
#           'Socialist Party': 2,
#           'South': 1,
#           'United States': 1,
#           'Venezuela': 5,
#           'Venezuelan': 4}),
#  'Commission': Counter({'Andrzej Duda': 1,
#           'Axel Springer': 1,
#           'Duda': 2,
#           'EU': 1,
#           'European Commission': 1,
#           'German': 1,
#           'Jaroslaw Kaczynski': 1,
#           'Justice Party': 1,
#           'Kaczynski': 5,
#           'Next Target Kaczynski': 1,
#           'PiS': 5,
#           'Poland': 12,
#           'Polsat': 1,
#           'Scripps Network Interactive': 1,
#           'Supreme Court': 3,
#           'TVN': 1,
#           'U.S.': 1,
#           'Viktor Orban': 1,
#           'Warsaw': 4,
#           'Zygmunt': 1}),
#  'Congress': Counter({'Barack Obama': 2,
#           'Barria': 2,
#           'CNN': 4,
#           'Corker': 2,
#           'Democratic': 2,
#           'Donald Trump': 4,
#           'Edward Fishman': 2,
#           'European Union': 2,
#           'Finland': 4,
#           'Finnish': 2,
#           'G20': 2,
#           'Germany': 2,
#           'Hamburg': 2,
#           'Iran': 4,
#           'Kremlin': 2,
#           'Moscow': 8,
#           'Mueller': 6,
#           'North Korea': 4,
#           'Obama': 4,
#           'Putin': 4,
#           'Representatives': 2,
#           'Republican': 4,
#           'Republican Trump': 2,
#           'Russia': 6,
#           'Russian': 14,
#           'Sarah Sanders': 2,
#           'Sauli Niinisto': 2,
#           'Scaramucci': 2,
#           'Senate': 8,
#           'Sessions': 2,
#           'Speaker Ryan': 2,
#           'Special Counsel Robert Mueller': 2,
#           'State Department': 2,
#           'Trump': 20,
#           'U.S.': 10,
#           'U.S. House': 6,
#           'Ukraine': 2,
#           'United States': 2,
#           'Vladimir Putin': 4,
#           'Washington': 2,
#           'White House': 6}),
#  'Connie Yates': Counter({'Britain': 2,
#           'British': 1,
#           'Charlie': 24,
#           'Charlie Gard': 2,
#           'Chris Gard': 2,
#           'Christmas': 1,
#           'DNA': 1,
#           'Donald Trump': 1,
#           'European Court': 1,
#           'Francis': 1,
#           'Great Ormond Street': 1,
#           'Great Ormond Street Hospital': 4,
#           'High Court': 3,
#           'Human Rights': 1,
#           'LONDON': 1,
#           'London': 1,
#           'Nicholas Francis': 1,
#           'Pope Francis': 1,
#           'Reuters': 1,
#           'U.S.': 1,
#           'United States': 3,
#           'Yates': 1}),
#  'Corker': Counter({'Barack Obama': 1,
#           'Barria': 1,
#           'CNN': 2,
#           'Congress': 2,
#           'Democratic': 1,
#           'Donald Trump': 2,
#           'Edward Fishman': 1,
#           'European Union': 1,
#           'Finland': 2,
#           'Finnish': 1,
#           'G20': 1,
#           'Germany': 1,
#           'Hamburg': 1,
#           'Iran': 2,
#           'Kremlin': 1,
#           'Moscow': 4,
#           'Mueller': 3,
#           'North Korea': 2,
#           'Obama': 2,
#           'Putin': 2,
#           'Representatives': 1,
#           'Republican': 2,
#           'Republican Trump': 1,
#           'Russia': 3,
#           'Russian': 7,
#           'Sarah Sanders': 1,
#           'Sauli Niinisto': 1,
#           'Scaramucci': 1,
#           'Senate': 4,
#           'Sessions': 1,
#           'Speaker Ryan': 1,
#           'Special Counsel Robert Mueller': 1,
#           'State Department': 1,
#           'Trump': 10,
#           'U.S.': 5,
#           'U.S. House': 3,
#           'Ukraine': 1,
#           'United States': 1,
#           'Vladimir Putin': 2,
#           'Washington': 1,
#           'White House': 3}),
#  'Cynthia Osterman': Counter({'Alaska': 1,
#           'Army': 2,
#           'Capitol Hill': 1,
#           'DIA': 1,
#           'David Brunnstrom': 1,
#           'Defense Intelligence Agency': 1,
#           'General Paul Selva': 1,
#           'Grant': 1,
#           'Idrees Ali': 1,
#           'Korean': 1,
#           'Milley': 1,
#           'National Press Club': 1,
#           'North': 1,
#           'North Korea': 9,
#           'Pentagon': 1,
#           'Phil Stewart': 1,
#           'Pyongyang': 1,
#           'Senate Armed Services Committee': 1,
#           'Staff': 1,
#           'U.S.': 7,
#           'U.S. Army': 1,
#           'United States': 2,
#           'WASHINGTON': 1,
#           'Washington': 2}),
#  'DIA': Counter({'Alaska': 1,
#           'Army': 2,
#           'Capitol Hill': 1,
#           'Cynthia Osterman': 1,
#           'David Brunnstrom': 1,
#           'Defense Intelligence Agency': 1,
#           'General Paul Selva': 1,
#           'Grant': 1,
#           'Idrees Ali': 1,
#           'Korean': 1,
#           'Milley': 1,
#           'National Press Club': 1,
#           'North': 1,
#           'North Korea': 9,
#           'Pentagon': 1,
#           'Phil Stewart': 1,
#           'Pyongyang': 1,
#           'Senate Armed Services Committee': 1,
#           'Staff': 1,
#           'U.S.': 7,
#           'U.S. Army': 1,
#           'United States': 2,
#           'WASHINGTON': 1,
#           'Washington': 2}),
#  'DNA': Counter({'Britain': 2,
#           'British': 1,
#           'Charlie': 24,
#           'Charlie Gard': 2,
#           'Chris Gard': 2,
#           'Christmas': 1,
#           'Connie Yates': 1,
#           'Donald Trump': 1,
#           'European Court': 1,
#           'Francis': 1,
#           'Great Ormond Street': 1,
#           'Great Ormond Street Hospital': 4,
#           'High Court': 3,
#           'Human Rights': 1,
#           'LONDON': 1,
#           'London': 1,
#           'Nicholas Francis': 1,
#           'Pope Francis': 1,
#           'Reuters': 1,
#           'U.S.': 1,
#           'United States': 3,
#           'Yates': 1}),
#  'Damascus': Counter({'Assad': 1,
#           'Bashar': 1,
#           'Hmeymim': 1,
#           'Latakia': 1,
#           'MOSCOW': 1,
#           'Middle East': 1,
#           'Moscow': 2,
#           'Putin': 2,
#           'REUTERS': 1,
#           'Russia': 5,
#           'Russian': 3,
#           'Syria': 2,
#           'Syrian': 1,
#           'Vladimir Putin': 2,
#           'Zhukovsky': 1}),
#  'David Brunnstrom': Counter({'Alaska': 1,
#           'Army': 2,
#           'Capitol Hill': 1,
#           'Cynthia Osterman': 1,
#           'DIA': 1,
#           'Defense Intelligence Agency': 1,
#           'General Paul Selva': 1,
#           'Grant': 1,
#           'Idrees Ali': 1,
#           'Korean': 1,
#           'Milley': 1,
#           'National Press Club': 1,
#           'North': 1,
#           'North Korea': 9,
#           'Pentagon': 1,
#           'Phil Stewart': 1,
#           'Pyongyang': 1,
#           'Senate Armed Services Committee': 1,
#           'Staff': 1,
#           'U.S.': 7,
#           'U.S. Army': 1,
#           'United States': 2,
#           'WASHINGTON': 1,
#           'Washington': 2}),
#  'Defence Ministry': Counter({'American': 2,
#           'Britain': 2,
#           'Democratic National Committee': 2,
#           'Dmitry Peskov': 2,
#           'Emmanuel Macron': 6,
#           'Facebook': 10,
#           'Fancy Bear': 2,
#           'France': 8,
#           'French': 12,
#           'GRU': 8,
#           'Jack Stubbs': 2,
#           'Jonathan Weber': 2,
#           'Joseph Menn': 2,
#           'Kremlin': 4,
#           'Le Mans': 2,
#           'Le Pen': 2,
#           'Le Touquet': 2,
#           'LinkedIn': 2,
#           'MI5': 2,
#           'Macron': 16,
#           'Marine Le Pen': 2,
#           'Michel Rose': 2,
#           'Moscow': 2,
#           'Mounir Mahjoubi': 2,
#           'PHOTO': 4,
#           'Paris': 2,
#           'Ross Colvin': 2,
#           'Russia': 8,
#           'Russian': 8,
#           'SAN': 2,
#           'San Francisco': 2,
#           'U.S.': 6}),
#  'Defense Intelligence Agency': Counter({'Alaska': 1,
#           'Army': 2,
#           'Capitol Hill': 1,
#           'Cynthia Osterman': 1,
#           'DIA': 1,
#           'David Brunnstrom': 1,
#           'General Paul Selva': 1,
#           'Grant': 1,
#           'Idrees Ali': 1,
#           'Korean': 1,
#           'Milley': 1,
#           'National Press Club': 1,
#           'North': 1,
#           'North Korea': 9,
#           'Pentagon': 1,
#           'Phil Stewart': 1,
#           'Pyongyang': 1,
#           'Senate Armed Services Committee': 1,
#           'Staff': 1,
#           'U.S.': 7,
#           'U.S. Army': 1,
#           'United States': 2,
#           'WASHINGTON': 1,
#           'Washington': 2}),
#  'Democratic': Counter({'Barack Obama': 1,
#           'Barria': 1,
#           'CNN': 2,
#           'Congress': 2,
#           'Corker': 1,
#           'Donald Trump': 2,
#           'Edward Fishman': 1,
#           'European Union': 1,
#           'Finland': 2,
#           'Finnish': 1,
#           'G20': 1,
#           'Germany': 1,
#           'Hamburg': 1,
#           'Iran': 2,
#           'Kremlin': 1,
#           'Moscow': 4,
#           'Mueller': 3,
#           'North Korea': 2,
#           'Obama': 2,
#           'Putin': 2,
#           'Representatives': 1,
#           'Republican': 2,
#           'Republican Trump': 1,
#           'Russia': 3,
#           'Russian': 7,
#           'Sarah Sanders': 1,
#           'Sauli Niinisto': 1,
#           'Scaramucci': 1,
#           'Senate': 4,
#           'Sessions': 1,
#           'Speaker Ryan': 1,
#           'Special Counsel Robert Mueller': 1,
#           'State Department': 1,
#           'Trump': 10,
#           'U.S.': 5,
#           'U.S. House': 3,
#           'Ukraine': 1,
#           'United States': 1,
#           'Vladimir Putin': 2,
#           'Washington': 1,
#           'White House': 3}),
#  'Democratic National Committee': Counter({'American': 2,
#           'Britain': 2,
#           'Defence Ministry': 2,
#           'Dmitry Peskov': 2,
#           'Emmanuel Macron': 6,
#           'Facebook': 10,
#           'Fancy Bear': 2,
#           'France': 8,
#           'French': 12,
#           'GRU': 8,
#           'Jack Stubbs': 2,
#           'Jonathan Weber': 2,
#           'Joseph Menn': 2,
#           'Kremlin': 4,
#           'Le Mans': 2,
#           'Le Pen': 2,
#           'Le Touquet': 2,
#           'LinkedIn': 2,
#           'MI5': 2,
#           'Macron': 16,
#           'Marine Le Pen': 2,
#           'Michel Rose': 2,
#           'Moscow': 2,
#           'Mounir Mahjoubi': 2,
#           'PHOTO': 4,
#           'Paris': 2,
#           'Ross Colvin': 2,
#           'Russia': 8,
#           'Russian': 8,
#           'SAN': 2,
#           'San Francisco': 2,
#           'U.S.': 6}),
#  'Democratic Unity': Counter({'Amazonas': 1,
#           'American': 1,
#           'Avianca': 1,
#           'Barinas': 2,
#           'Carabobo': 1,
#           'Caracas': 6,
#           'Clashes': 1,
#           'Colombian': 1,
#           'Donald Trump': 1,
#           'Hugo Chavez': 1,
#           'INE': 1,
#           'Maduro': 3,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'National Electoral Council': 1,
#           'Nestor Reverol': 1,
#           'Nicolas Maduro': 3,
#           'OPEC': 1,
#           'Penal Forum': 1,
#           'Petare': 1,
#           'Ramon Alvarez': 1,
#           'Riot': 1,
#           'Socialist Party': 2,
#           'South': 1,
#           'United States': 1,
#           'Venezuela': 5,
#           'Venezuelan': 4}),
#  'Dmitry Peskov': Counter({'American': 2,
#           'Britain': 2,
#           'Defence Ministry': 2,
#           'Democratic National Committee': 2,
#           'Emmanuel Macron': 6,
#           'Facebook': 10,
#           'Fancy Bear': 2,
#           'France': 8,
#           'French': 12,
#           'GRU': 8,
#           'Jack Stubbs': 2,
#           'Jonathan Weber': 2,
#           'Joseph Menn': 2,
#           'Kremlin': 4,
#           'Le Mans': 2,
#           'Le Pen': 2,
#           'Le Touquet': 2,
#           'LinkedIn': 2,
#           'MI5': 2,
#           'Macron': 16,
#           'Marine Le Pen': 2,
#           'Michel Rose': 2,
#           'Moscow': 2,
#           'Mounir Mahjoubi': 2,
#           'PHOTO': 4,
#           'Paris': 2,
#           'Ross Colvin': 2,
#           'Russia': 8,
#           'Russian': 8,
#           'SAN': 2,
#           'San Francisco': 2,
#           'U.S.': 6}),
#  'Donald Trump': Counter({'Abdullah': 2,
#           'Amazonas': 1,
#           'American': 1,
#           'Amman': 1,
#           'Aqsa': 2,
#           'Avianca': 1,
#           'Barack Obama': 2,
#           'Barinas': 2,
#           'Barria': 2,
#           'Benjamin Netanyahu': 1,
#           'Britain': 2,
#           'British': 1,
#           'CCTV': 1,
#           'CNN': 4,
#           'Carabobo': 1,
#           'Caracas': 6,
#           'Charlie': 24,
#           'Charlie Gard': 2,
#           'Chris Gard': 2,
#           'Christmas': 1,
#           'Clashes': 1,
#           'Colombian': 1,
#           'Congress': 4,
#           'Connie Yates': 1,
#           'Corker': 2,
#           'DNA': 1,
#           'Democratic': 2,
#           'Democratic Unity': 1,
#           'East Jerusalem': 4,
#           'Edward Fishman': 2,
#           'Embassy': 2,
#           'European Court': 1,
#           'European Union': 2,
#           'Finland': 4,
#           'Finnish': 2,
#           'Francis': 1,
#           'G20': 2,
#           'Germany': 2,
#           'Great Ormond Street': 1,
#           'Great Ormond Street Hospital': 4,
#           'Hamburg': 2,
#           'High Court': 3,
#           'Holy Land': 1,
#           'Hugo Chavez': 1,
#           'Human Rights': 1,
#           'INE': 1,
#           'Iran': 4,
#           'Islam': 1,
#           'Israel': 12,
#           'Israeli': 8,
#           'JERUSALEM': 1,
#           'Jerusalem': 4,
#           'Jordan': 3,
#           'Judaism': 1,
#           'Kremlin': 2,
#           'L5N1KI8C8': 1,
#           'LONDON': 1,
#           'London': 1,
#           'Maduro': 3,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'Middle East': 2,
#           'Moscow': 8,
#           'Mueller': 6,
#           'Muslim': 3,
#           'Muslim Arab': 1,
#           'Muslims': 4,
#           'Naftali Bennett': 1,
#           'National Electoral Council': 1,
#           'Nestor Reverol': 1,
#           'Netanyahu': 8,
#           'Nicholas Francis': 1,
#           'Nicolas Maduro': 3,
#           'Noble Sanctuary': 3,
#           'North Korea': 4,
#           'OPEC': 1,
#           'Obama': 4,
#           'Old City': 2,
#           'Palestinian': 6,
#           'Palestinians': 1,
#           'Penal Forum': 1,
#           'Petare': 1,
#           'Pope Francis': 1,
#           'Putin': 4,
#           'Ramon Alvarez': 1,
#           'Representatives': 2,
#           'Republican': 4,
#           'Republican Trump': 2,
#           'Reuters': 1,
#           'Riot': 1,
#           'Russia': 6,
#           'Russian': 14,
#           'Sarah Sanders': 2,
#           'Sauli Niinisto': 2,
#           'Scaramucci': 2,
#           'Senate': 8,
#           'Sessions': 2,
#           'Socialist Party': 2,
#           'South': 1,
#           'Speaker Ryan': 2,
#           'Special Counsel Robert Mueller': 2,
#           'State Department': 2,
#           'Temple': 1,
#           'Temple Mount': 1,
#           'Trump': 20,
#           'U.S.': 12,
#           'U.S. House': 6,
#           'Ukraine': 2,
#           'United Nations': 2,
#           'United States': 6,
#           'Venezuela': 5,
#           'Venezuelan': 4,
#           'Vladimir Putin': 4,
#           'Waqf': 1,
#           'Waqf Muslim': 1,
#           'Washington': 2,
#           'West Bank': 1,
#           'Western Wall': 1,
#           'White House': 6,
#           'Yates': 1}),
#  'Duda': Counter({'Andrzej Duda': 2,
#           'Axel Springer': 2,
#           'Commission': 2,
#           'EU': 2,
#           'European Commission': 2,
#           'German': 2,
#           'Jaroslaw Kaczynski': 2,
#           'Justice Party': 2,
#           'Kaczynski': 10,
#           'Next Target Kaczynski': 2,
#           'PiS': 10,
#           'Poland': 24,
#           'Polsat': 2,
#           'Scripps Network Interactive': 2,
#           'Supreme Court': 6,
#           'TVN': 2,
#           'U.S.': 2,
#           'Viktor Orban': 2,
#           'Warsaw': 8,
#           'Zygmunt': 2}),
#  'EU': Counter({'Andrzej Duda': 1,
#           'Axel Springer': 1,
#           'Commission': 1,
#           'Duda': 2,
#           'European Commission': 1,
#           'German': 1,
#           'Jaroslaw Kaczynski': 1,
#           'Justice Party': 1,
#           'Kaczynski': 5,
#           'Next Target Kaczynski': 1,
#           'PiS': 5,
#           'Poland': 12,
#           'Polsat': 1,
#           'Scripps Network Interactive': 1,
#           'Supreme Court': 3,
#           'TVN': 1,
#           'U.S.': 1,
#           'Viktor Orban': 1,
#           'Warsaw': 4,
#           'Zygmunt': 1}),
#  'East Jerusalem': Counter({'Abdullah': 8,
#           'Amman': 4,
#           'Aqsa': 8,
#           'Benjamin Netanyahu': 4,
#           'CCTV': 4,
#           'Donald Trump': 4,
#           'Embassy': 8,
#           'Holy Land': 4,
#           'Islam': 4,
#           'Israel': 48,
#           'Israeli': 32,
#           'JERUSALEM': 4,
#           'Jerusalem': 16,
#           'Jordan': 12,
#           'Judaism': 4,
#           'L5N1KI8C8': 4,
#           'Middle East': 8,
#           'Muslim': 12,
#           'Muslim Arab': 4,
#           'Muslims': 16,
#           'Naftali Bennett': 4,
#           'Netanyahu': 32,
#           'Noble Sanctuary': 12,
#           'Old City': 8,
#           'Palestinian': 24,
#           'Palestinians': 4,
#           'Temple': 4,
#           'Temple Mount': 4,
#           'U.S.': 4,
#           'United Nations': 8,
#           'Waqf': 4,
#           'Waqf Muslim': 4,
#           'West Bank': 4,
#           'Western Wall': 4}),
#  'Edward Fishman': Counter({'Barack Obama': 1,
#           'Barria': 1,
#           'CNN': 2,
#           'Congress': 2,
#           'Corker': 1,
#           'Democratic': 1,
#           'Donald Trump': 2,
#           'European Union': 1,
#           'Finland': 2,
#           'Finnish': 1,
#           'G20': 1,
#           'Germany': 1,
#           'Hamburg': 1,
#           'Iran': 2,
#           'Kremlin': 1,
#           'Moscow': 4,
#           'Mueller': 3,
#           'North Korea': 2,
#           'Obama': 2,
#           'Putin': 2,
#           'Representatives': 1,
#           'Republican': 2,
#           'Republican Trump': 1,
#           'Russia': 3,
#           'Russian': 7,
#           'Sarah Sanders': 1,
#           'Sauli Niinisto': 1,
#           'Scaramucci': 1,
#           'Senate': 4,
#           'Sessions': 1,
#           'Speaker Ryan': 1,
#           'Special Counsel Robert Mueller': 1,
#           'State Department': 1,
#           'Trump': 10,
#           'U.S.': 5,
#           'U.S. House': 3,
#           'Ukraine': 1,
#           'United States': 1,
#           'Vladimir Putin': 2,
#           'Washington': 1,
#           'White House': 3}),
#  'Embassy': Counter({'Abdullah': 4,
#           'Amman': 2,
#           'Aqsa': 4,
#           'Benjamin Netanyahu': 2,
#           'CCTV': 2,
#           'Donald Trump': 2,
#           'East Jerusalem': 8,
#           'Holy Land': 2,
#           'Islam': 2,
#           'Israel': 24,
#           'Israeli': 16,
#           'JERUSALEM': 2,
#           'Jerusalem': 8,
#           'Jordan': 6,
#           'Judaism': 2,
#           'L5N1KI8C8': 2,
#           'Middle East': 4,
#           'Muslim': 6,
#           'Muslim Arab': 2,
#           'Muslims': 8,
#           'Naftali Bennett': 2,
#           'Netanyahu': 16,
#           'Noble Sanctuary': 6,
#           'Old City': 4,
#           'Palestinian': 12,
#           'Palestinians': 2,
#           'Temple': 2,
#           'Temple Mount': 2,
#           'U.S.': 2,
#           'United Nations': 4,
#           'Waqf': 2,
#           'Waqf Muslim': 2,
#           'West Bank': 2,
#           'Western Wall': 2}),
#  'Emmanuel Macron': Counter({'American': 6,
#           'Britain': 6,
#           'Defence Ministry': 6,
#           'Democratic National Committee': 6,
#           'Dmitry Peskov': 6,
#           'Facebook': 30,
#           'Fancy Bear': 6,
#           'France': 24,
#           'French': 36,
#           'GRU': 24,
#           'Jack Stubbs': 6,
#           'Jonathan Weber': 6,
#           'Joseph Menn': 6,
#           'Kremlin': 12,
#           'Le Mans': 6,
#           'Le Pen': 6,
#           'Le Touquet': 6,
#           'LinkedIn': 6,
#           'MI5': 6,
#           'Macron': 48,
#           'Marine Le Pen': 6,
#           'Michel Rose': 6,
#           'Moscow': 6,
#           'Mounir Mahjoubi': 6,
#           'PHOTO': 12,
#           'Paris': 6,
#           'Ross Colvin': 6,
#           'Russia': 24,
#           'Russian': 24,
#           'SAN': 6,
#           'San Francisco': 6,
#           'U.S.': 18}),
#  'European Commission': Counter({'Andrzej Duda': 1,
#           'Axel Springer': 1,
#           'Commission': 1,
#           'Duda': 2,
#           'EU': 1,
#           'German': 1,
#           'Jaroslaw Kaczynski': 1,
#           'Justice Party': 1,
#           'Kaczynski': 5,
#           'Next Target Kaczynski': 1,
#           'PiS': 5,
#           'Poland': 12,
#           'Polsat': 1,
#           'Scripps Network Interactive': 1,
#           'Supreme Court': 3,
#           'TVN': 1,
#           'U.S.': 1,
#           'Viktor Orban': 1,
#           'Warsaw': 4,
#           'Zygmunt': 1}),
#  'European Court': Counter({'Britain': 2,
#           'British': 1,
#           'Charlie': 24,
#           'Charlie Gard': 2,
#           'Chris Gard': 2,
#           'Christmas': 1,
#           'Connie Yates': 1,
#           'DNA': 1,
#           'Donald Trump': 1,
#           'Francis': 1,
#           'Great Ormond Street': 1,
#           'Great Ormond Street Hospital': 4,
#           'High Court': 3,
#           'Human Rights': 1,
#           'LONDON': 1,
#           'London': 1,
#           'Nicholas Francis': 1,
#           'Pope Francis': 1,
#           'Reuters': 1,
#           'U.S.': 1,
#           'United States': 3,
#           'Yates': 1}),
#  'European Union': Counter({'Barack Obama': 1,
#           'Barria': 1,
#           'CNN': 2,
#           'Congress': 2,
#           'Corker': 1,
#           'Democratic': 1,
#           'Donald Trump': 2,
#           'Edward Fishman': 1,
#           'Finland': 2,
#           'Finnish': 1,
#           'G20': 1,
#           'Germany': 1,
#           'Hamburg': 1,
#           'Iran': 2,
#           'Kremlin': 1,
#           'Moscow': 4,
#           'Mueller': 3,
#           'North Korea': 2,
#           'Obama': 2,
#           'Putin': 2,
#           'Representatives': 1,
#           'Republican': 2,
#           'Republican Trump': 1,
#           'Russia': 3,
#           'Russian': 7,
#           'Sarah Sanders': 1,
#           'Sauli Niinisto': 1,
#           'Scaramucci': 1,
#           'Senate': 4,
#           'Sessions': 1,
#           'Speaker Ryan': 1,
#           'Special Counsel Robert Mueller': 1,
#           'State Department': 1,
#           'Trump': 10,
#           'U.S.': 5,
#           'U.S. House': 3,
#           'Ukraine': 1,
#           'United States': 1,
#           'Vladimir Putin': 2,
#           'Washington': 1,
#           'White House': 3}),
#  'Facebook': Counter({'American': 10,
#           'Britain': 10,
#           'Defence Ministry': 10,
#           'Democratic National Committee': 10,
#           'Dmitry Peskov': 10,
#           'Emmanuel Macron': 30,
#           'Fancy Bear': 10,
#           'France': 40,
#           'French': 60,
#           'GRU': 40,
#           'Jack Stubbs': 10,
#           'Jonathan Weber': 10,
# ...
#           'France': 4,
#           'Francis': 3,
#           'G20': 1,
#           'General Paul Selva': 2,
#           'Germany': 1,
#           'Grant': 2,
#           'Great Ormond Street': 3,
#           'Great Ormond Street Hospital': 12,
#           'Hamburg': 1,
#           'High Court': 9,
#           'Hugo Chavez': 1,
#           'Human Rights': 3,
#           'INE': 1,
#           'Idrees Ali': 2,
#           'International Criminal Court': 2,
#           'Iran': 4,
#           'Korean': 2,
#           'Kremlin': 1,
#           'LONDON': 3,
#           'London': 3,
#           'Maduro': 3,
#           'Martinez Casares': 1,
#           'Merida': 1,
#           'Michele Sison': 2,
#           'Milley': 2,
#           'Moscow': 4,
#           'Mueller': 5,
#           'National Electoral Council': 1,
#           'National Press Club': 2,
#           'Nestor Reverol': 1,
#           'New York': 2,
#           'Nicholas Francis': 3,
#           'Nicolas Maduro': 3,
#           'North': 2,
#           'North Korea': 20,
#           'OPEC': 1,
#           'Obama': 2,
#           'Obstacles': 2,
#           'Penal Forum': 1,
#           'Pentagon': 2,
#           'Petare': 1,
#           'Phil Stewart': 2,
#           'Pope Francis': 3,
#           'Putin': 2,
#           'Pyongyang': 2,
#           'Ramon Alvarez': 1,
#           'Representatives': 1,
#           'Republican': 2,
#           'Republican Trump': 1,
#           'Reuters': 3,
#           'Riot': 1,
#           'Russia': 17,
#           'Russian': 7,
#           'Sarah Sanders': 1,
#           'Sauli Niinisto': 1,
#           'Scaramucci': 1,
#           'Security Council': 10,
#           'Senate': 4,
#           'Senate Armed Services Committee': 2,
#           'Sessions': 1,
#           'Socialist Party': 2,
#           'South': 1,
#           'Speaker Ryan': 1,
#           'Special Counsel Robert Mueller': 1,
#           'Staff': 2,
#           'State Department': 1,
#           'Syria': 12,
#           'Syrian': 14,
#           'Trump': 10,
#           'Turkey': 2,
#           'U.N.': 6,
#           'U.S.': 26,
#           'U.S. Army': 2,
#           'U.S. House': 3,
#           'UNITED NATIONS': 2,
#           'Ukraine': 1,
#           'United Nations': 2,
#           'United Nations Headquarters': 2,
#           'United Nations Matthew Rycroft': 2,
#           'Ursula Mueller': 2,
#           'Venezuela': 5,
#           'Venezuelan': 4,
#           'Vladimir Putin': 2,
#           'WASHINGTON': 2,
#           'Washington': 5,
#           'White House': 3,
#           'Yates': 3}),
#  'University': Counter({'Ahmed Mohammed': 1,
#           'Islamist': 1,
#           'Lake Chad Basin': 2,
#           'Maiduguri': 1,
#           'NNPC': 2,
#           'Nigeria': 2,
#           'Nigerian National Petroleum Corporation': 1,
#           'Northeastern Nigeria': 1}),
#  'Ursula Mueller': Counter({'Assad': 1,
#           'Bashar': 1,
#           'Britain': 6,
#           'China': 2,
#           'France': 2,
#           'International Criminal Court': 1,
#           'Iran': 1,
#           'Michele Sison': 1,
#           'Mueller': 1,
#           'New York': 1,
#           'Obstacles': 1,
#           'Russia': 7,
#           'Security Council': 5,
#           'Syria': 6,
#           'Syrian': 7,
#           'Turkey': 1,
#           'U.N.': 3,
#           'U.S.': 2,
#           'UNITED NATIONS': 1,
#           'United Nations': 1,
#           'United Nations Headquarters': 1,
#           'United Nations Matthew Rycroft': 1,
#           'United States': 2}),
#  'Venezuela': Counter({'Amazonas': 5,
#           'American': 5,
#           'Avianca': 5,
#           'Barinas': 10,
#           'Carabobo': 5,
#           'Caracas': 30,
#           'Clashes': 5,
#           'Colombian': 5,
#           'Democratic Unity': 5,
#           'Donald Trump': 5,
#           'Hugo Chavez': 5,
#           'INE': 5,
#           'Maduro': 15,
#           'Martinez Casares': 5,
#           'Merida': 5,
#           'National Electoral Council': 5,
#           'Nestor Reverol': 5,
#           'Nicolas Maduro': 15,
#           'OPEC': 5,
#           'Penal Forum': 5,
#           'Petare': 5,
#           'Ramon Alvarez': 5,
#           'Riot': 5,
#           'Socialist Party': 10,
#           'South': 5,
#           'United States': 5,
#           'Venezuelan': 20}),
#  'Venezuelan': Counter({'Amazonas': 4,
#           'American': 4,
#           'Avianca': 4,
#           'Barinas': 8,
#           'Carabobo': 4,
#           'Caracas': 24,
#           'Clashes': 4,
#           'Colombian': 4,
#           'Democratic Unity': 4,
#           'Donald Trump': 4,
#           'Hugo Chavez': 4,
#           'INE': 4,
#           'Maduro': 12,
#           'Martinez Casares': 4,
#           'Merida': 4,
#           'National Electoral Council': 4,
#           'Nestor Reverol': 4,
#           'Nicolas Maduro': 12,
#           'OPEC': 4,
#           'Penal Forum': 4,
#           'Petare': 4,
#           'Ramon Alvarez': 4,
#           'Riot': 4,
#           'Socialist Party': 8,
#           'South': 4,
#           'United States': 4,
#           'Venezuela': 20}),
#  'Viktor Orban': Counter({'Andrzej Duda': 1,
#           'Axel Springer': 1,
#           'Commission': 1,
#           'Duda': 2,
#           'EU': 1,
#           'European Commission': 1,
#           'German': 1,
#           'Jaroslaw Kaczynski': 1,
#           'Justice Party': 1,
#           'Kaczynski': 5,
#           'Next Target Kaczynski': 1,
#           'PiS': 5,
#           'Poland': 12,
#           'Polsat': 1,
#           'Scripps Network Interactive': 1,
#           'Supreme Court': 3,
#           'TVN': 1,
#           'U.S.': 1,
#           'Warsaw': 4,
#           'Zygmunt': 1}),
#  'Vladimir Putin': Counter({'Assad': 2,
#           'Barack Obama': 2,
#           'Barria': 2,
#           'Bashar': 2,
#           'CNN': 4,
#           'Congress': 4,
#           'Corker': 2,
#           'Damascus': 2,
#           'Democratic': 2,
#           'Donald Trump': 4,
#           'Edward Fishman': 2,
#           'European Union': 2,
#           'Finland': 4,
#           'Finnish': 2,
#           'G20': 2,
#           'Germany': 2,
#           'Hamburg': 2,
#           'Hmeymim': 2,
#           'Iran': 4,
#           'Kremlin': 2,
#           'Latakia': 2,
#           'MOSCOW': 2,
#           'Middle East': 2,
#           'Moscow': 12,
#           'Mueller': 6,
#           'North Korea': 4,
#           'Obama': 4,
#           'Putin': 8,
#           'REUTERS': 2,
#           'Representatives': 2,
#           'Republican': 4,
#           'Republican Trump': 2,
#           'Russia': 16,
#           'Russian': 20,
#           'Sarah Sanders': 2,
#           'Sauli Niinisto': 2,
#           'Scaramucci': 2,
#           'Senate': 8,
#           'Sessions': 2,
#           'Speaker Ryan': 2,
#           'Special Counsel Robert Mueller': 2,
#           'State Department': 2,
#           'Syria': 4,
#           'Syrian': 2,
#           'Trump': 20,
#           'U.S.': 10,
#           'U.S. House': 6,
#           'Ukraine': 2,
#           'United States': 2,
#           'Washington': 2,
#           'White House': 6,
#           'Zhukovsky': 2}),
#  'WASHINGTON': Counter({'Alaska': 1,
#           'Army': 2,
#           'Capitol Hill': 1,
#           'Cynthia Osterman': 1,
#           'DIA': 1,
#           'David Brunnstrom': 1,
#           'Defense Intelligence Agency': 1,
#           'General Paul Selva': 1,
#           'Grant': 1,
#           'Idrees Ali': 1,
#           'Korean': 1,
#           'Milley': 1,
#           'National Press Club': 1,
#           'North': 1,
#           'North Korea': 9,
#           'Pentagon': 1,
#           'Phil Stewart': 1,
#           'Pyongyang': 1,
#           'Senate Armed Services Committee': 1,
#           'Staff': 1,
#           'U.S.': 7,
#           'U.S. Army': 1,
#           'United States': 2,
#           'Washington': 2}),
#  'Waqf': Counter({'Abdullah': 2,
#           'Amman': 1,
#           'Aqsa': 2,
#           'Benjamin Netanyahu': 1,
#           'CCTV': 1,
#           'Donald Trump': 1,
#           'East Jerusalem': 4,
#           'Embassy': 2,
#           'Holy Land': 1,
#           'Islam': 1,
#           'Israel': 12,
#           'Israeli': 8,
#           'JERUSALEM': 1,
#           'Jerusalem': 4,
#           'Jordan': 3,
#           'Judaism': 1,
#           'L5N1KI8C8': 1,
#           'Middle East': 2,
#           'Muslim': 3,
#           'Muslim Arab': 1,
#           'Muslims': 4,
#           'Naftali Bennett': 1,
#           'Netanyahu': 8,
#           'Noble Sanctuary': 3,
#           'Old City': 2,
#           'Palestinian': 6,
#           'Palestinians': 1,
#           'Temple': 1,
#           'Temple Mount': 1,
#           'U.S.': 1,
#           'United Nations': 2,
#           'Waqf Muslim': 1,
#           'West Bank': 1,
#           'Western Wall': 1}),
#  'Waqf Muslim': Counter({'Abdullah': 2,
#           'Amman': 1,
#           'Aqsa': 2,
#           'Benjamin Netanyahu': 1,
#           'CCTV': 1,
#           'Donald Trump': 1,
#           'East Jerusalem': 4,
#           'Embassy': 2,
#           'Holy Land': 1,
#           'Islam': 1,
#           'Israel': 12,
#           'Israeli': 8,
#           'JERUSALEM': 1,
#           'Jerusalem': 4,
#           'Jordan': 3,
#           'Judaism': 1,
#           'L5N1KI8C8': 1,
#           'Middle East': 2,
#           'Muslim': 3,
#           'Muslim Arab': 1,
#           'Muslims': 4,
#           'Naftali Bennett': 1,
#           'Netanyahu': 8,
#           'Noble Sanctuary': 3,
#           'Old City': 2,
#           'Palestinian': 6,
#           'Palestinians': 1,
#           'Temple': 1,
#           'Temple Mount': 1,
#           'U.S.': 1,
#           'United Nations': 2,
#           'Waqf': 1,
#           'West Bank': 1,
#           'Western Wall': 1}),
#  'Warsaw': Counter({'Andrzej Duda': 4,
#           'Axel Springer': 4,
#           'Commission': 4,
#           'Duda': 8,
#           'EU': 4,
#           'European Commission': 4,
#           'German': 4,
#           'Jaroslaw Kaczynski': 4,
#           'Justice Party': 4,
#           'Kaczynski': 20,
#           'Next Target Kaczynski': 4,
#           'PiS': 20,
#           'Poland': 48,
#           'Polsat': 4,
#           'Scripps Network Interactive': 4,
#           'Supreme Court': 12,
#           'TVN': 4,
#           'U.S.': 4,
#           'Viktor Orban': 4,
#           'Zygmunt': 4}),
#  'Washington': Counter({'Alaska': 2,
#           'Army': 4,
#           'Barack Obama': 1,
#           'Barria': 1,
#           'CNN': 2,
#           'Capitol Hill': 2,
#           'Congress': 2,
#           'Corker': 1,
#           'Cynthia Osterman': 2,
#           'DIA': 2,
#           'David Brunnstrom': 2,
#           'Defense Intelligence Agency': 2,
#           'Democratic': 1,
#           'Donald Trump': 2,
#           'Edward Fishman': 1,
#           'European Union': 1,
#           'Finland': 2,
#           'Finnish': 1,
#           'G20': 1,
#           'General Paul Selva': 2,
#           'Germany': 1,
#           'Grant': 2,
#           'Hamburg': 1,
#           'Idrees Ali': 2,
#           'Iran': 2,
#           'Korean': 2,
#           'Kremlin': 1,
#           'Milley': 2,
#           'Moscow': 4,
#           'Mueller': 3,
#           'National Press Club': 2,
#           'North': 2,
#           'North Korea': 20,
#           'Obama': 2,
#           'Pentagon': 2,
#           'Phil Stewart': 2,
#           'Putin': 2,
#           'Pyongyang': 2,
#           'Representatives': 1,
#           'Republican': 2,
#           'Republican Trump': 1,
#           'Russia': 3,
#           'Russian': 7,
#           'Sarah Sanders': 1,
#           'Sauli Niinisto': 1,
#           'Scaramucci': 1,
#           'Senate': 4,
#           'Senate Armed Services Committee': 2,
#           'Sessions': 1,
#           'Speaker Ryan': 1,
#           'Special Counsel Robert Mueller': 1,
#           'Staff': 2,
#           'State Department': 1,
#           'Trump': 10,
#           'U.S.': 19,
#           'U.S. Army': 2,
#           'U.S. House': 3,
#           'Ukraine': 1,
#           'United States': 5,
#           'Vladimir Putin': 2,
#           'WASHINGTON': 2,
#           'White House': 3}),
#  'West Bank': Counter({'Abdullah': 2,
#           'Amman': 1,
#           'Aqsa': 2,
#           'Benjamin Netanyahu': 1,
#           'CCTV': 1,
#           'Donald Trump': 1,
#           'East Jerusalem': 4,
#           'Embassy': 2,
#           'Holy Land': 1,
#           'Islam': 1,
#           'Israel': 12,
#           'Israeli': 8,
#           'JERUSALEM': 1,
#           'Jerusalem': 4,
#           'Jordan': 3,
#           'Judaism': 1,
#           'L5N1KI8C8': 1,
#           'Middle East': 2,
#           'Muslim': 3,
#           'Muslim Arab': 1,
#           'Muslims': 4,
#           'Naftali Bennett': 1,
#           'Netanyahu': 8,
#           'Noble Sanctuary': 3,
#           'Old City': 2,
#           'Palestinian': 6,
#           'Palestinians': 1,
#           'Temple': 1,
#           'Temple Mount': 1,
#           'U.S.': 1,
#           'United Nations': 2,
#           'Waqf': 1,
#           'Waqf Muslim': 1,
#           'Western Wall': 1}),
#  'Western Wall': Counter({'Abdullah': 2,
#           'Amman': 1,
#           'Aqsa': 2,
#           'Benjamin Netanyahu': 1,
#           'CCTV': 1,
#           'Donald Trump': 1,
#           'East Jerusalem': 4,
#           'Embassy': 2,
#           'Holy Land': 1,
#           'Islam': 1,
#           'Israel': 12,
#           'Israeli': 8,
#           'JERUSALEM': 1,
#           'Jerusalem': 4,
#           'Jordan': 3,
#           'Judaism': 1,
#           'L5N1KI8C8': 1,
#           'Middle East': 2,
#           'Muslim': 3,
#           'Muslim Arab': 1,
#           'Muslims': 4,
#           'Naftali Bennett': 1,
#           'Netanyahu': 8,
#           'Noble Sanctuary': 3,
#           'Old City': 2,
#           'Palestinian': 6,
#           'Palestinians': 1,
#           'Temple': 1,
#           'Temple Mount': 1,
#           'U.S.': 1,
#           'United Nations': 2,
#           'Waqf': 1,
#           'Waqf Muslim': 1,
#           'West Bank': 1}),
#  'White House': Counter({'Barack Obama': 3,
#           'Barria': 3,
#           'CNN': 6,
#           'Congress': 6,
#           'Corker': 3,
#           'Democratic': 3,
#           'Donald Trump': 6,
#           'Edward Fishman': 3,
#           'European Union': 3,
#           'Finland': 6,
#           'Finnish': 3,
#           'G20': 3,
#           'Germany': 3,
#           'Hamburg': 3,
#           'Iran': 6,
#           'Kremlin': 3,
#           'Moscow': 12,
#           'Mueller': 9,
#           'North Korea': 6,
#           'Obama': 6,
#           'Putin': 6,
#           'Representatives': 3,
#           'Republican': 6,
#           'Republican Trump': 3,
#           'Russia': 9,
#           'Russian': 21,
#           'Sarah Sanders': 3,
#           'Sauli Niinisto': 3,
#           'Scaramucci': 3,
#           'Senate': 12,
#           'Sessions': 3,
#           'Speaker Ryan': 3,
#           'Special Counsel Robert Mueller': 3,
#           'State Department': 3,
#           'Trump': 30,
#           'U.S.': 15,
#           'U.S. House': 9,
#           'Ukraine': 3,
#           'United States': 3,
#           'Vladimir Putin': 6,
#           'Washington': 3}),
#  'Yates': Counter({'Britain': 2,
#           'British': 1,
#           'Charlie': 24,
#           'Charlie Gard': 2,
#           'Chris Gard': 2,
#           'Christmas': 1,
#           'Connie Yates': 1,
#           'DNA': 1,
#           'Donald Trump': 1,
#           'European Court': 1,
#           'Francis': 1,
#           'Great Ormond Street': 1,
#           'Great Ormond Street Hospital': 4,
#           'High Court': 3,
#           'Human Rights': 1,
#           'LONDON': 1,
#           'London': 1,
#           'Nicholas Francis': 1,
#           'Pope Francis': 1,
#           'Reuters': 1,
#           'U.S.': 1,
#           'United States': 3}),
#  'Zhukovsky': Counter({'Assad': 1,
#           'Bashar': 1,
#           'Damascus': 1,
#           'Hmeymim': 1,
#           'Latakia': 1,
#           'MOSCOW': 1,
#           'Middle East': 1,
#           'Moscow': 2,
#           'Putin': 2,
#           'REUTERS': 1,
#           'Russia': 5,
#           'Russian': 3,
#           'Syria': 2,
#           'Syrian': 1,
#           'Vladimir Putin': 2}),
#  'Zygmunt': Counter({'Andrzej Duda': 1,
#           'Axel Springer': 1,
#           'Commission': 1,
#           'Duda': 2,
#           'EU': 1,
#           'European Commission': 1,
#           'German': 1,
#           'Jaroslaw Kaczynski': 1,
#           'Justice Party': 1,
#           'Kaczynski': 5,
#           'Next Target Kaczynski': 1,
#           'PiS': 5,
#           'Poland': 12,
#           'Polsat': 1,
#           'Scripps Network Interactive': 1,
#           'Supreme Court': 3,
#           'TVN': 1,
#           'U.S.': 1,
#           'Viktor Orban': 1,
#           'Warsaw': 4})}

# %%
create_db()
# Out:
# {}

# %%
update_single(extraction)
# Out:
# {'American': Counter({'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Britain': Counter({'American': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Defence Ministry': Counter({'American': 1,
#           'Britain': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Democratic National Committee': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Dmitry Peskov': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Emmanuel Macron': Counter({'American': 3,
#           'Britain': 3,
#           'Defence Ministry': 3,
#           'Democratic National Committee': 3,
#           'Dmitry Peskov': 3,
#           'Facebook': 15,
#           'Fancy Bear': 3,
#           'France': 12,
#           'French': 18,
#           'GRU': 12,
#           'Jack Stubbs': 3,
#           'Jonathan Weber': 3,
#           'Joseph Menn': 3,
#           'Kremlin': 6,
#           'Le Mans': 3,
#           'Le Pen': 3,
#           'Le Touquet': 3,
#           'LinkedIn': 3,
#           'MI5': 3,
#           'Macron': 24,
#           'Marine Le Pen': 3,
#           'Michel Rose': 3,
#           'Moscow': 3,
#           'Mounir Mahjoubi': 3,
#           'PHOTO': 6,
#           'Paris': 3,
#           'Ross Colvin': 3,
#           'Russia': 12,
#           'Russian': 12,
#           'SAN': 3,
#           'San Francisco': 3,
#           'U.S.': 9}),
#  'Facebook': Counter({'American': 5,
#           'Britain': 5,
#           'Defence Ministry': 5,
#           'Democratic National Committee': 5,
#           'Dmitry Peskov': 5,
#           'Emmanuel Macron': 15,
#           'Fancy Bear': 5,
#           'France': 20,
#           'French': 30,
#           'GRU': 20,
#           'Jack Stubbs': 5,
#           'Jonathan Weber': 5,
#           'Joseph Menn': 5,
#           'Kremlin': 10,
#           'Le Mans': 5,
#           'Le Pen': 5,
#           'Le Touquet': 5,
#           'LinkedIn': 5,
#           'MI5': 5,
#           'Macron': 40,
#           'Marine Le Pen': 5,
#           'Michel Rose': 5,
#           'Moscow': 5,
#           'Mounir Mahjoubi': 5,
#           'PHOTO': 10,
#           'Paris': 5,
#           'Ross Colvin': 5,
#           'Russia': 20,
#           'Russian': 20,
#           'SAN': 5,
#           'San Francisco': 5,
#           'U.S.': 15}),
#  'Fancy Bear': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'France': Counter({'American': 4,
#           'Britain': 4,
#           'Defence Ministry': 4,
#           'Democratic National Committee': 4,
#           'Dmitry Peskov': 4,
#           'Emmanuel Macron': 12,
#           'Facebook': 20,
#           'Fancy Bear': 4,
#           'French': 24,
#           'GRU': 16,
#           'Jack Stubbs': 4,
#           'Jonathan Weber': 4,
#           'Joseph Menn': 4,
#           'Kremlin': 8,
#           'Le Mans': 4,
#           'Le Pen': 4,
#           'Le Touquet': 4,
#           'LinkedIn': 4,
#           'MI5': 4,
#           'Macron': 32,
#           'Marine Le Pen': 4,
#           'Michel Rose': 4,
#           'Moscow': 4,
#           'Mounir Mahjoubi': 4,
#           'PHOTO': 8,
#           'Paris': 4,
#           'Ross Colvin': 4,
#           'Russia': 16,
#           'Russian': 16,
#           'SAN': 4,
#           'San Francisco': 4,
#           'U.S.': 12}),
#  'French': Counter({'American': 6,
#           'Britain': 6,
#           'Defence Ministry': 6,
#           'Democratic National Committee': 6,
#           'Dmitry Peskov': 6,
#           'Emmanuel Macron': 18,
#           'Facebook': 30,
#           'Fancy Bear': 6,
#           'France': 24,
#           'GRU': 24,
#           'Jack Stubbs': 6,
#           'Jonathan Weber': 6,
#           'Joseph Menn': 6,
#           'Kremlin': 12,
#           'Le Mans': 6,
#           'Le Pen': 6,
#           'Le Touquet': 6,
#           'LinkedIn': 6,
#           'MI5': 6,
#           'Macron': 48,
#           'Marine Le Pen': 6,
#           'Michel Rose': 6,
#           'Moscow': 6,
#           'Mounir Mahjoubi': 6,
#           'PHOTO': 12,
#           'Paris': 6,
#           'Ross Colvin': 6,
#           'Russia': 24,
#           'Russian': 24,
#           'SAN': 6,
#           'San Francisco': 6,
#           'U.S.': 18}),
#  'GRU': Counter({'American': 4,
#           'Britain': 4,
#           'Defence Ministry': 4,
#           'Democratic National Committee': 4,
#           'Dmitry Peskov': 4,
#           'Emmanuel Macron': 12,
#           'Facebook': 20,
#           'Fancy Bear': 4,
#           'France': 16,
#           'French': 24,
#           'Jack Stubbs': 4,
#           'Jonathan Weber': 4,
#           'Joseph Menn': 4,
#           'Kremlin': 8,
#           'Le Mans': 4,
#           'Le Pen': 4,
#           'Le Touquet': 4,
#           'LinkedIn': 4,
#           'MI5': 4,
#           'Macron': 32,
#           'Marine Le Pen': 4,
#           'Michel Rose': 4,
#           'Moscow': 4,
#           'Mounir Mahjoubi': 4,
#           'PHOTO': 8,
#           'Paris': 4,
#           'Ross Colvin': 4,
#           'Russia': 16,
#           'Russian': 16,
#           'SAN': 4,
#           'San Francisco': 4,
#           'U.S.': 12}),
#  'Jack Stubbs': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Jonathan Weber': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Joseph Menn': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Kremlin': Counter({'American': 2,
#           'Britain': 2,
#           'Defence Ministry': 2,
#           'Democratic National Committee': 2,
#           'Dmitry Peskov': 2,
#           'Emmanuel Macron': 6,
#           'Facebook': 10,
#           'Fancy Bear': 2,
#           'France': 8,
#           'French': 12,
#           'GRU': 8,
#           'Jack Stubbs': 2,
#           'Jonathan Weber': 2,
#           'Joseph Menn': 2,
#           'Le Mans': 2,
#           'Le Pen': 2,
#           'Le Touquet': 2,
#           'LinkedIn': 2,
#           'MI5': 2,
#           'Macron': 16,
#           'Marine Le Pen': 2,
#           'Michel Rose': 2,
#           'Moscow': 2,
#           'Mounir Mahjoubi': 2,
#           'PHOTO': 4,
#           'Paris': 2,
#           'Ross Colvin': 2,
#           'Russia': 8,
#           'Russian': 8,
#           'SAN': 2,
#           'San Francisco': 2,
#           'U.S.': 6}),
#  'Le Mans': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Le Pen': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Le Touquet': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'LinkedIn': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'MI5': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Macron': Counter({'American': 8,
#           'Britain': 8,
#           'Defence Ministry': 8,
#           'Democratic National Committee': 8,
#           'Dmitry Peskov': 8,
#           'Emmanuel Macron': 24,
#           'Facebook': 40,
#           'Fancy Bear': 8,
#           'France': 32,
#           'French': 48,
#           'GRU': 32,
#           'Jack Stubbs': 8,
#           'Jonathan Weber': 8,
#           'Joseph Menn': 8,
#           'Kremlin': 16,
#           'Le Mans': 8,
#           'Le Pen': 8,
#           'Le Touquet': 8,
#           'LinkedIn': 8,
#           'MI5': 8,
#           'Marine Le Pen': 8,
#           'Michel Rose': 8,
#           'Moscow': 8,
#           'Mounir Mahjoubi': 8,
#           'PHOTO': 16,
#           'Paris': 8,
#           'Ross Colvin': 8,
#           'Russia': 32,
#           'Russian': 32,
#           'SAN': 8,
#           'San Francisco': 8,
#           'U.S.': 24}),
#  'Marine Le Pen': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Michel Rose': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Moscow': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Mounir Mahjoubi': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'PHOTO': Counter({'American': 2,
#           'Britain': 2,
#           'Defence Ministry': 2,
#           'Democratic National Committee': 2,
#           'Dmitry Peskov': 2,
#           'Emmanuel Macron': 6,
#           'Facebook': 10,
#           'Fancy Bear': 2,
#           'France': 8,
#           'French': 12,
#           'GRU': 8,
#           'Jack Stubbs': 2,
#           'Jonathan Weber': 2,
#           'Joseph Menn': 2,
#           'Kremlin': 4,
#           'Le Mans': 2,
#           'Le Pen': 2,
#           'Le Touquet': 2,
#           'LinkedIn': 2,
#           'MI5': 2,
#           'Macron': 16,
#           'Marine Le Pen': 2,
#           'Michel Rose': 2,
#           'Moscow': 2,
#           'Mounir Mahjoubi': 2,
#           'Paris': 2,
#           'Ross Colvin': 2,
#           'Russia': 8,
#           'Russian': 8,
#           'SAN': 2,
#           'San Francisco': 2,
#           'U.S.': 6}),
#  'Paris': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Ross Colvin': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'Russia': Counter({'American': 4,
#           'Britain': 4,
#           'Defence Ministry': 4,
#           'Democratic National Committee': 4,
#           'Dmitry Peskov': 4,
#           'Emmanuel Macron': 12,
#           'Facebook': 20,
#           'Fancy Bear': 4,
#           'France': 16,
#           'French': 24,
#           'GRU': 16,
#           'Jack Stubbs': 4,
#           'Jonathan Weber': 4,
#           'Joseph Menn': 4,
#           'Kremlin': 8,
#           'Le Mans': 4,
#           'Le Pen': 4,
#           'Le Touquet': 4,
#           'LinkedIn': 4,
#           'MI5': 4,
#           'Macron': 32,
#           'Marine Le Pen': 4,
#           'Michel Rose': 4,
#           'Moscow': 4,
#           'Mounir Mahjoubi': 4,
#           'PHOTO': 8,
#           'Paris': 4,
#           'Ross Colvin': 4,
#           'Russian': 16,
#           'SAN': 4,
#           'San Francisco': 4,
#           'U.S.': 12}),
#  'Russian': Counter({'American': 4,
#           'Britain': 4,
#           'Defence Ministry': 4,
#           'Democratic National Committee': 4,
#           'Dmitry Peskov': 4,
#           'Emmanuel Macron': 12,
#           'Facebook': 20,
#           'Fancy Bear': 4,
#           'France': 16,
#           'French': 24,
#           'GRU': 16,
#           'Jack Stubbs': 4,
#           'Jonathan Weber': 4,
#           'Joseph Menn': 4,
#           'Kremlin': 8,
#           'Le Mans': 4,
#           'Le Pen': 4,
#           'Le Touquet': 4,
#           'LinkedIn': 4,
#           'MI5': 4,
#           'Macron': 32,
#           'Marine Le Pen': 4,
#           'Michel Rose': 4,
#           'Moscow': 4,
#           'Mounir Mahjoubi': 4,
#           'PHOTO': 8,
#           'Paris': 4,
#           'Ross Colvin': 4,
#           'Russia': 16,
#           'SAN': 4,
#           'San Francisco': 4,
#           'U.S.': 12}),
#  'SAN': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'San Francisco': 1,
#           'U.S.': 3}),
#  'San Francisco': Counter({'American': 1,
#           'Britain': 1,
#           'Defence Ministry': 1,
#           'Democratic National Committee': 1,
#           'Dmitry Peskov': 1,
#           'Emmanuel Macron': 3,
#           'Facebook': 5,
#           'Fancy Bear': 1,
#           'France': 4,
#           'French': 6,
#           'GRU': 4,
#           'Jack Stubbs': 1,
#           'Jonathan Weber': 1,
#           'Joseph Menn': 1,
#           'Kremlin': 2,
#           'Le Mans': 1,
#           'Le Pen': 1,
#           'Le Touquet': 1,
#           'LinkedIn': 1,
#           'MI5': 1,
#           'Macron': 8,
#           'Marine Le Pen': 1,
#           'Michel Rose': 1,
#           'Moscow': 1,
#           'Mounir Mahjoubi': 1,
#           'PHOTO': 2,
#           'Paris': 1,
#           'Ross Colvin': 1,
#           'Russia': 4,
#           'Russian': 4,
#           'SAN': 1,
#           'U.S.': 3}),
#  'U.S.': Counter({'American': 3,
#           'Britain': 3,
#           'Defence Ministry': 3,
#           'Democratic National Committee': 3,
#           'Dmitry Peskov': 3,
#           'Emmanuel Macron': 9,
#           'Facebook': 15,
#           'Fancy Bear': 3,
#           'France': 12,
#           'French': 18,
#           'GRU': 12,
#           'Jack Stubbs': 3,
#           'Jonathan Weber': 3,
#           'Joseph Menn': 3,
#           'Kremlin': 6,
#           'Le Mans': 3,
#           'Le Pen': 3,
#           'Le Touquet': 3,
#           'LinkedIn': 3,
#           'MI5': 3,
#           'Macron': 24,
#           'Marine Le Pen': 3,
#           'Michel Rose': 3,
#           'Moscow': 3,
#           'Mounir Mahjoubi': 3,
#           'PHOTO': 6,
#           'Paris': 3,
#           'Ross Colvin': 3,
#           'Russia': 12,
#           'Russian': 12,
#           'SAN': 3,
#           'San Francisco': 3})}

# %%
top_related("Donald Trump")
# Out:
# [('Charlie', 24),
#  ('Trump', 20),
#  ('Russian', 14),
#  ('U.S.', 12),
#  ('Israel', 12),
#  ('Senate', 8),
#  ('Moscow', 8),
#  ('Netanyahu', 8),
#  ('Israeli', 8),
#  ('Mueller', 6),
#  ('White House', 6),
#  ('U.S. House', 6),
#  ('United States', 6),
#  ('Russia', 6),
#  ('Palestinian', 6),
#  ('Caracas', 6),
#  ('Venezuela', 5),
#  ('CNN', 4),
#  ('Republican', 4),
#  ('Putin', 4),
#  ('Obama', 4),
#  ('Finland', 4),
#  ('Iran', 4),
#  ('North Korea', 4),
#  ('Congress', 4),
#  ('Vladimir Putin', 4),
#  ('Great Ormond Street Hospital', 4),
#  ('Jerusalem', 4),
#  ('East Jerusalem', 4),
#  ('Muslims', 4),
#  ('Venezuelan', 4),
#  ('High Court', 3),
#  ('Noble Sanctuary', 3),
#  ('Jordan', 3),
#  ('Muslim', 3),
#  ('Maduro', 3),
#  ('Nicolas Maduro', 3),
#  ('Speaker Ryan', 2),
#  ('Sessions', 2),
#  ('Special Counsel Robert Mueller', 2),
#  ('Sauli Niinisto', 2),
#  ('Finnish', 2),
#  ('State Department', 2),
#  ('Edward Fishman', 2),
#  ('Sarah Sanders', 2),
#  ('Democratic', 2),
#  ('Corker', 2),
#  ('Barack Obama', 2),
#  ('European Union', 2),
#  ('Ukraine', 2),
#  ('Kremlin', 2),
#  ('Scaramucci', 2),
#  ('Representatives', 2),
#  ('Republican Trump', 2),
#  ('Washington', 2),
#  ('Barria', 2),
#  ('Germany', 2),
#  ('Hamburg', 2),
#  ('G20', 2),
#  ('Britain', 2),
#  ('Chris Gard', 2),
#  ('Charlie Gard', 2),
#  ('United Nations', 2),
#  ('Middle East', 2),
#  ('Old City', 2),
#  ('Aqsa', 2),
#  ('Abdullah', 2),
#  ('Embassy', 2),
#  ('Socialist Party', 2),
#  ('Barinas', 2),
#  ('Human Rights', 1),
#  ('European Court', 1),
#  ('Christmas', 1),
#  ('DNA', 1),
#  ('Great Ormond Street', 1),
#  ('Yates', 1),
#  ('London', 1),
#  ('Connie Yates', 1),
#  ('Pope Francis', 1),
#  ('Reuters', 1),
#  ('Francis', 1),
#  ('Nicholas Francis', 1),
#  ('LONDON', 1),
#  ('British', 1),
#  ('Naftali Bennett', 1),
#  ('Holy Land', 1),
#  ('Western Wall', 1),
#  ('Judaism', 1),
#  ('L5N1KI8C8', 1),
#  ('Temple', 1),
#  ('Waqf', 1),
#  ('Waqf Muslim', 1),
#  ('West Bank', 1),
#  ('Temple Mount', 1),
#  ('Amman', 1),
#  ('Muslim Arab', 1),
#  ('Palestinians', 1),
#  ('Benjamin Netanyahu', 1),
#  ('CCTV', 1),
#  ('Islam', 1),
#  ('JERUSALEM', 1),
#  ('INE', 1),
#  ('National Electoral Council', 1),
#  ('Amazonas', 1),
#  ('Democratic Unity', 1),
#  ('Avianca', 1),
#  ('Colombian', 1),
#  ('Nestor Reverol', 1),
#  ('Penal Forum', 1),
#  ('Petare', 1),
#  ('Merida', 1),
#  ('Carabobo', 1),
#  ('Riot', 1),
#  ('Ramon Alvarez', 1),
#  ('Hugo Chavez', 1),
#  ('American', 1),
#  ('South', 1),
#  ('OPEC', 1),
#  ('Martinez Casares', 1),
#  ('Clashes', 1)]

# %%
def common_entities(docs, k=None):
    """
    Given a list of token-lists, return the most common entity among 
    """
