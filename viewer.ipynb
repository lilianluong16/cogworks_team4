# %%
import database
database.retrieve_song_features("Castle of Glass")
# Out:
# {(5081, 2896, 0),
#  (15471, 6050, 15),
#  (11358, 7288, 0),
#  (13899, 9410, 13),
#  (7256, 6470, 11),
#  (12069, 9905, 0),
#  (16289, 14836, 2),
#  (22050, 10368, 7),
#  (19476, 17635, 12),
#  (20208, 14642, 6),
#  (10346, 656, 10),
#  (9668, 6287, 7),
#  (20208, 8807, 10),
#  (1991, 549, 10),
#  (19509, 4209, 1),
#  (5490, 3186, 4),
#  (16074, 3983, 8),
#  (12230, 7741, 1),
#  (19003, 10680, 5),
#  (21834, 14265, 2),
#  (17635, 16149, 0),
#  (19239, 2077, 5),
#  (10249, 8074, 9),
#  (10626, 9259, 12),
#  (3014, 2540, 0),
#  (12909, 10002, 0),
#  (17194, 2444, 3),
#  (9883, 8279, 12),
#  (20295, 6341, 12),
#  (11897, 990, 14),
#  (20811, 15977, 6),
#  (20208, 8634, 1),
#  (13307, 4984, 7),
#  (18152, 14879, 0),
#  (21274, 9549, 15),
#  (21931, 6438, 2),
#  (11423, 11046, 0),
#  (14814, 12866, 6),
#  (18550, 17032, 0),
#  (18023, 9453, 15),
#  (17398, 13264, 5),
#  (6029, 2239, 8),
#  (19842, 15966, 4),
#  (13124, 5189, 0),
#  (9819, 1722, 12),
#  (17818, 2217, 2),
# ...
