# %%
import quandl
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

from mygrad import Tensor
from mygrad.nnet.activations import relu, sigmoid, softmax
from mygrad.nnet.layers import dense

# %%
quandl.ApiConfig.api_key = "GRoxis4s_5SA67pQ3wvL"

# %%
data = quandl.get("EOD/UNH")

# %%
data
# Out:
#               Open     High       Low   Close     Volume  Dividend  Split  \
# Date
# 1990-03-26    9.50    9.500    9.3800    9.38    12900.0       0.0    1.0
# 1990-03-27    9.38    9.870    9.3800    9.87   122300.0       0.0    1.0
# 1990-03-28    9.87    9.870    9.6200    9.62    48800.0       0.0    1.0
# 1990-03-29    9.87    9.870    9.7500    9.75    16800.0       0.0    1.0
# 1990-03-30    9.87    9.870    9.6200    9.75    54900.0       0.0    1.0
# 1990-04-02    9.62    9.870    9.3800    9.87    76600.0       0.0    1.0
# 1990-04-03   10.00   10.250    9.7500   10.00    87900.0       0.0    1.0
# 1990-04-04   10.13   10.250    9.8700   10.00   125100.0       0.0    1.0
# 1990-04-05   10.13   10.380   10.1300   10.25   123800.0       0.0    1.0
# 1990-04-06   10.38   10.500   10.2500   10.38    39800.0       0.0    1.0
# 1990-04-09   10.38   10.500   10.1300   10.13    89800.0       0.0    1.0
# 1990-04-10   10.13   10.250    9.8700    9.87    66200.0       0.0    1.0
# ...

# %%
data = quandl.get("EOD/UNH", returns="numpy")
data
# Out:
# rec.array([ (datetime.datetime(1990, 3, 26, 0, 0), 9.5, 9.5, 9.38, 9.38, 12900.0, 0.0, 1.0, 0.26175374003384716, 0.26175374003384716, 0.2584473770018407, 0.2584473770018407, 412800.0),
#  (datetime.datetime(1990, 3, 27, 0, 0), 9.38, 9.87, 9.38, 9.87, 122300.0, 0.0, 1.0, 0.2584473770018407, 0.2719483593825338, 0.2584473770018407, 0.2719483593825338, 3913600.0),
#  (datetime.datetime(1990, 3, 28, 0, 0), 9.87, 9.87, 9.62, 9.62, 48800.0, 0.0, 1.0, 0.2719483593825338, 0.2719483593825338, 0.2650601030658536, 0.2650601030658536, 1561600.0),
#  ...,
#  (datetime.datetime(2017, 7, 27, 0, 0), 190.24, 190.49, 188.46, 188.93, 2631353.0, 0.0, 1.0, 190.24, 190.49, 188.46, 188.93, 2631353.0),
#  (datetime.datetime(2017, 7, 28, 0, 0), 189.11, 191.244, 187.6, 191.15, 1925049.0, 0.0, 1.0, 189.11, 191.244, 187.6, 191.15, 1925049.0),
#  (datetime.datetime(2017, 7, 31, 0, 0), 191.59, 192.61, 191.14, 191.81, 3776476.0, 0.0, 1.0, 191.59, 192.61, 191.14, 191.81, 3776476.0)],
# ...

# %%
def calc_state(prev_state, current_inp, U, W):
    return relu(dense(U, current_inp) + dense(W, prev_state))

# %%
def calc_output(current_state, V):
    return softmax(dense(V, current_state))

# %%
def get_value(t):
    return data[t][8:12]

# %%
def RNN():
    u = Tensor(np.random.)
